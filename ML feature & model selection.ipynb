# %% [markdown]
# ## Import packages

# %%
# Standard libraries

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Handeling .wav files

import librosa
from librosa import feature

# Machine Learning

from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score, RepeatedStratifiedKFold
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.feature_selection import RFE

from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

from functools import reduce

# data vizualisation

import matplotlib 
import matplotlib.pyplot as plt
import seaborn as sns

#saving & loading ML method
import pickle

# %% [markdown]
# ### Increase size of scrollable output

# %%
from IPython.core.display import display, HTML
display(HTML("<style>div.output_scroll { height: 56em; }</style>"))
# Out:
# <style>div.output_scroll { height: 56em; }</style>

# %% [markdown]
# ## Function that concatenates all dB levels for a certain machine

# %%
def concatenate_pd(machine):
    
    # Opening the .csv files
    
    df_6dB=pd.read_csv(f'Librosa_features_{machine}_6dB.csv')
    df_0dB=pd.read_csv(f'Librosa_features_{machine}_0dB.csv')
    df_min6dB=pd.read_csv(f'Librosa_features_{machine}_-6dB.csv')
    
    # Dropping the 'Unnamed: 0' column
    
    df_6dB.drop(columns = ['Unnamed: 0'], axis=1, inplace=True)
    df_0dB.drop(columns = ['Unnamed: 0'], axis=1, inplace=True)
    df_min6dB.drop(columns = ['Unnamed: 0'], axis=1, inplace=True)
    

    
    # Merging the .csv files into one DataFrame
    
    data_frames = [df_6dB, df_0dB, df_min6dB]
    df_merged = pd.concat(data_frames)
    
    
    return df_merged

# %% [markdown]
# ## Undersampling

# %%
def undersampling(machine):  
    minority_class_len = len(machine[machine['normal(0)/abnormal(1)'] == 1])
    majority_class_indices = machine[machine['normal(0)/abnormal(1)'] == 0].index
    random_majority_indices = np.random.choice(majority_class_indices, minority_class_len , replace= False)
    minority_class_indices  = machine[machine['normal(0)/abnormal(1)'] == 1].index

    under_sample_indices = np.concatenate( [minority_class_indices , random_majority_indices])
    under_sample = machine.loc[under_sample_indices]
    return under_sample

# %% [markdown]
# ## Splitting data in train, test and validation set

# %%
def split_data(samples):  
    X = under_sample.drop(columns = ['normal(0)/abnormal(1)'])
    y = under_sample['normal(0)/abnormal(1)']

    # 20% of the overal data will seperated for later validation of the model

    X_model, X_valid, y_model, y_valid = train_test_split(X, y, test_size=0.3, random_state = 42, stratify = y)

    # 60% of the overal data (75% of X_model, y_model) will be used to create a training set for the model
    # 20% of the overal data (25% of X_model, y_model) will be used to create a testing set for the model

    X_train, X_test, y_train, y_test = train_test_split(X_model,
                                                       y_model,
                                                       test_size = 1/3,
                                                       random_state = 10, stratify=y_model)
    return X_train, X_test, X_valid, y_train, y_test, y_valid

# %% [markdown]
# ## Create pipeline

# %%
pipeline = Pipeline([('scaler', StandardScaler()), ('clf', SVC())])

# %% [markdown]
# ## ML feature & model selection

# %%
def model_selection(X_train, X_test, X_valid, y_train, y_test, y_valid): 

    y_pred = []
    clfs = []
    # append classifiers to pipeline
    clfs.append(DecisionTreeClassifier())
    clfs.append(RandomForestClassifier())

    for index in range(1,len(X_train.columns)):

        for classifier in clfs:

            print("----------------------------------------------")
            print("----------------------------------------------")
            print(classifier)
            print("----------------------------------------------")
            print("----------------------------------------------")

            sel = RFE(classifier, n_features_to_select = index)
            sel.fit(X_train, y_train)
            features = X_train.columns[sel.get_support()]
            X_train_rfe = sel.transform(X_train)
            X_test_rfe = sel.transform(X_test)
            print('Selected Feature', index)
            print(features)

            classifier.fit(X_train_rfe, y_train)
            y_pred= classifier.predict(X_test_rfe)
            scores = cross_val_score(pipeline, X_train_rfe, y_train, cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1))
            
            print("----------------------------------------------")
            print("TRAIN-TEST")
            print("----------------------------------------------")


            print('confusion matrix', classifier)
            print(confusion_matrix(y_test, y_pred))
            print('classification report')
            print(classification_report(y_test, y_pred))
            print('accuracy score')
            print(accuracy_score(y_test, y_pred))
            

            X_valid_rfe = sel.transform(X_valid)
            y_pred = classifier.predict(X_valid_rfe)

            print("----------------------------------------------")
            print("TRAIN-VALIDATION")
            print("----------------------------------------------")

            print('confusion matrix', classifier)
            print(confusion_matrix(y_valid, y_pred))
            print('classification report')
            print(classification_report(y_valid, y_pred))
            print('accuracy score')
            print(accuracy_score(y_valid, y_pred))

# %% [markdown]
# ## ML on best model

# %%
def best_model_selection(X_train, X_test, X_valid, y_train, y_test, y_valid, index, best_classifier): 
    
    pipeline = Pipeline([('scaler', StandardScaler()), ('clf', best_classifier)])
    
    y_pred = []
    clfs = []
    
    # append classifiers to pipeline
    clfs.append(best_classifier)
    
    print("----------------------------------------------")
    print("----------------------------------------------")
    print(best_classifier)
    print("----------------------------------------------")
    print("----------------------------------------------")

    sel = RFE(best_classifier, n_features_to_select = index)
    sel.fit(X_train, y_train)
    features = X_train.columns[sel.get_support()]
    X_train_rfe = sel.transform(X_train)
    X_test_rfe = sel.transform(X_test)
    print('Selected Feature', index)
    print(features)

    best_classifier.fit(X_train_rfe, y_train)
    # save the model to disk
    filename = 'finalized_model.sav'
    pickle.dump(best_classifier, open(filename, 'wb'))
    
    y_pred= best_classifier.predict(X_test_rfe)
    scores = cross_val_score(pipeline, X_train_rfe, y_train, cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1))
            
    print("----------------------------------------------")
    print("TRAIN-TEST")
    print("----------------------------------------------")


    print('confusion matrix', best_classifier)
    print(confusion_matrix(y_test, y_pred))
    print('classification report')
    print(classification_report(y_test, y_pred))
    print('accuracy score')
    print(accuracy_score(y_test, y_pred))
            

    X_valid_rfe = sel.transform(X_valid)
    y_pred = best_classifier.predict(X_valid_rfe)

    print("----------------------------------------------")
    print("TRAIN-VALIDATION")
    print("----------------------------------------------")

    print('confusion matrix', best_classifier)
    print(confusion_matrix(y_valid, y_pred))
    print('classification report')
    print(classification_report(y_valid, y_pred))
    print('accuracy score')
    print(accuracy_score(y_valid, y_pred))
    
    return filename

# %% [markdown]
# ## Run ML on particular machine

# %%
machine=input('Which machine? ')
# Out:
# Which machine? fan

# %%
machine=concatenate_pd(machine)

# %%
samples=undersampling(machine)

# %%
X_train, X_test, X_valid, y_train, y_test, y_valid=split_data(samples)

# %%
model_selection(X_train, X_test, X_valid, y_train, y_test, y_valid)
# Out:
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 1
# Index(['melspectrogram_sum'], dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2342  755]
#  [ 424 2674]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.85      0.76      0.80      3097
#            1       0.78      0.86      0.82      3098
#
#     accuracy                           0.81      6195
#    macro avg       0.81      0.81      0.81      6195
# weighted avg       0.81      0.81      0.81      6195
#
# accuracy score
# 0.8096852300242131
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[3007  976]
#  [ 547 3435]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.85      0.75      0.80      3983
#            1       0.78      0.86      0.82      3982
#
#     accuracy                           0.81      7965
#    macro avg       0.81      0.81      0.81      7965
# weighted avg       0.81      0.81      0.81      7965
#
# accuracy score
# 0.8087884494664156
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 1
# Index(['rms'], dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2283  814]
#  [ 550 2548]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.81      0.74      0.77      3097
#            1       0.76      0.82      0.79      3098
#
#     accuracy                           0.78      6195
#    macro avg       0.78      0.78      0.78      6195
# weighted avg       0.78      0.78      0.78      6195
#
# accuracy score
# 0.779822437449556
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2959 1024]
#  [ 773 3209]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.79      0.74      0.77      3983
#            1       0.76      0.81      0.78      3982
#
#     accuracy                           0.77      7965
#    macro avg       0.78      0.77      0.77      7965
# weighted avg       0.78      0.77      0.77      7965
#
# accuracy score
# 0.7743879472693032
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 2
# Index(['melspectrogram', 'rms'], dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2714  383]
#  [ 238 2860]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90      3097
#            1       0.88      0.92      0.90      3098
#
#     accuracy                           0.90      6195
#    macro avg       0.90      0.90      0.90      6195
# weighted avg       0.90      0.90      0.90      6195
#
# accuracy score
# 0.8997578692493947
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[3417  566]
#  [ 317 3665]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.86      0.89      3983
#            1       0.87      0.92      0.89      3982
#
#     accuracy                           0.89      7965
#    macro avg       0.89      0.89      0.89      7965
# weighted avg       0.89      0.89      0.89      7965
#
# accuracy score
# 0.8891399874450722
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 2
# Index(['melspectrogram', 'rms'], dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2774  323]
#  [ 212 2886]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.91      3097
#            1       0.90      0.93      0.92      3098
#
#     accuracy                           0.91      6195
#    macro avg       0.91      0.91      0.91      6195
# weighted avg       0.91      0.91      0.91      6195
#
# accuracy score
# 0.9136400322841001
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[3500  483]
#  [ 288 3694]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90      3983
#            1       0.88      0.93      0.91      3982
#
#     accuracy                           0.90      7965
#    macro avg       0.90      0.90      0.90      7965
# weighted avg       0.90      0.90      0.90      7965
#
# accuracy score
# 0.9032015065913371
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 3
# Index(['melspectrogram', 'rms', 'spectral_flatness '], dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2775  322]
#  [ 191 2907]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.94      0.90      0.92      3097
#            1       0.90      0.94      0.92      3098
#
#     accuracy                           0.92      6195
#    macro avg       0.92      0.92      0.92      6195
# weighted avg       0.92      0.92      0.92      6195
#
# accuracy score
# 0.9171912832929782
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[3534  449]
#  [ 241 3741]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.94      0.89      0.91      3983
#            1       0.89      0.94      0.92      3982
#
#     accuracy                           0.91      7965
#    macro avg       0.91      0.91      0.91      7965
# weighted avg       0.91      0.91      0.91      7965
#
# accuracy score
# 0.9133709981167608
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 3
# Index(['melspectrogram_sum', 'rms', 'spectral_rolloff'], dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2886  211]
#  [ 149 2949]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      3097
#            1       0.93      0.95      0.94      3098
#
#     accuracy                           0.94      6195
#    macro avg       0.94      0.94      0.94      6195
# weighted avg       0.94      0.94      0.94      6195
#
# accuracy score
# 0.9418886198547215
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[3699  284]
#  [ 205 3777]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      3983
#            1       0.93      0.95      0.94      3982
#
#     accuracy                           0.94      7965
#    macro avg       0.94      0.94      0.94      7965
# weighted avg       0.94      0.94      0.94      7965
#
# accuracy score
# 0.9386064030131827
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 4
# Index(['melspectrogram', 'mfcc', 'rms', 'spectral_flatness '], dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2818  279]
#  [ 162 2936]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93      3097
#            1       0.91      0.95      0.93      3098
#
#     accuracy                           0.93      6195
#    macro avg       0.93      0.93      0.93      6195
# weighted avg       0.93      0.93      0.93      6195
#
# accuracy score
# 0.9288135593220339
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[3595  388]
#  [ 204 3778]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.90      0.92      3983
#            1       0.91      0.95      0.93      3982
#
#     accuracy                           0.93      7965
#    macro avg       0.93      0.93      0.93      7965
# weighted avg       0.93      0.93      0.93      7965
#
# accuracy score
# 0.9256748273697426
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 4
# Index(['melspectrogram', 'melspectrogram_std', 'rms', 'spectral_rolloff'], dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2892  205]
#  [ 142 2956]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      3097
#            1       0.94      0.95      0.94      3098
#
#     accuracy                           0.94      6195
#    macro avg       0.94      0.94      0.94      6195
# weighted avg       0.94      0.94      0.94      6195
#
# accuracy score
# 0.9439870863599678
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[3720  263]
#  [ 182 3800]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      3983
#            1       0.94      0.95      0.94      3982
#
#     accuracy                           0.94      7965
#    macro avg       0.94      0.94      0.94      7965
# weighted avg       0.94      0.94      0.94      7965
#
# accuracy score
# 0.9441305712492153
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 5
# Index(['melspectrogram_sum', 'mfcc', 'rms', 'spectral_flatness ',
#        'spectral_rolloff'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2839  258]
#  [ 148 2950]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.93      3097
#            1       0.92      0.95      0.94      3098
#
#     accuracy                           0.93      6195
#    macro avg       0.94      0.93      0.93      6195
# weighted avg       0.94      0.93      0.93      6195
#
# accuracy score
# 0.9344632768361582
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[3630  353]
#  [ 194 3788]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93      3983
#            1       0.91      0.95      0.93      3982
#
#     accuracy                           0.93      7965
#    macro avg       0.93      0.93      0.93      7965
# weighted avg       0.93      0.93      0.93      7965
#
# accuracy score
# 0.931324544883867
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 5
# Index(['melspectrogram', 'melspectrogram_sum', 'melspectrogram_std', 'rms',
#        'spectral_rolloff'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2875  222]
#  [ 148 2950]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      3097
#            1       0.93      0.95      0.94      3098
#
#     accuracy                           0.94      6195
#    macro avg       0.94      0.94      0.94      6195
# weighted avg       0.94      0.94      0.94      6195
#
# accuracy score
# 0.9402744148506861
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[3693  290]
#  [ 194 3788]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      3983
#            1       0.93      0.95      0.94      3982
#
#     accuracy                           0.94      7965
#    macro avg       0.94      0.94      0.94      7965
# weighted avg       0.94      0.94      0.94      7965
#
# accuracy score
# 0.9392341494036409
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 6
# Index(['melspectrogram', 'melspectrogram_sum', 'mfcc', 'rms',
#        'spectral_flatness ', 'spectral_rolloff'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2843  254]
#  [ 152 2946]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.93      3097
#            1       0.92      0.95      0.94      3098
#
#     accuracy                           0.93      6195
#    macro avg       0.93      0.93      0.93      6195
# weighted avg       0.93      0.93      0.93      6195
#
# accuracy score
# 0.9344632768361582
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[3628  355]
#  [ 202 3780]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93      3983
#            1       0.91      0.95      0.93      3982
#
#     accuracy                           0.93      7965
#    macro avg       0.93      0.93      0.93      7965
# weighted avg       0.93      0.93      0.93      7965
#
# accuracy score
# 0.9300690521029504
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 6
# Index(['melspectrogram', 'melspectrogram_sum', 'melspectrogram_std', 'rms',
#        'spectral_centroid', 'spectral_rolloff'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2911  186]
#  [ 120 2978]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95      3097
#            1       0.94      0.96      0.95      3098
#
#     accuracy                           0.95      6195
#    macro avg       0.95      0.95      0.95      6195
# weighted avg       0.95      0.95      0.95      6195
#
# accuracy score
# 0.9506053268765133
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[3715  268]
#  [ 162 3820]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.95      3983
#            1       0.93      0.96      0.95      3982
#
#     accuracy                           0.95      7965
#    macro avg       0.95      0.95      0.95      7965
# weighted avg       0.95      0.95      0.95      7965
#
# accuracy score
# 0.9460138104205901
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 7
# Index(['melspectrogram', 'melspectrogram_std', 'mfcc', 'rms',
#        'spectral_contrast', 'spectral_flatness ', 'spectral_rolloff'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2854  243]
#  [ 146 2952]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94      3097
#            1       0.92      0.95      0.94      3098
#
#     accuracy                           0.94      6195
#    macro avg       0.94      0.94      0.94      6195
# weighted avg       0.94      0.94      0.94      6195
#
# accuracy score
# 0.9372074253430186
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[3672  311]
#  [ 157 3825]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94      3983
#            1       0.92      0.96      0.94      3982
#
#     accuracy                           0.94      7965
#    macro avg       0.94      0.94      0.94      7965
# weighted avg       0.94      0.94      0.94      7965
#
# accuracy score
# 0.9412429378531073
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 7
# Index(['melspectrogram', 'melspectrogram_sum', 'melspectrogram_std', 'mfcc',
#        'rms', 'spectral_centroid', 'spectral_rolloff'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2952  145]
#  [ 115 2983]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96      3097
#            1       0.95      0.96      0.96      3098
#
#     accuracy                           0.96      6195
#    macro avg       0.96      0.96      0.96      6195
# weighted avg       0.96      0.96      0.96      6195
#
# accuracy score
# 0.9580306698950767
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[3761  222]
#  [ 146 3836]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95      3983
#            1       0.95      0.96      0.95      3982
#
#     accuracy                           0.95      7965
#    macro avg       0.95      0.95      0.95      7965
# weighted avg       0.95      0.95      0.95      7965
#
# accuracy score
# 0.9537978656622724
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 8
# Index(['melspectrogram', 'melspectrogram_sum', 'melspectrogram_std', 'mfcc',
#        'rms', 'spectral_contrast', 'spectral_flatness ', 'spectral_rolloff'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2861  236]
#  [ 136 2962]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94      3097
#            1       0.93      0.96      0.94      3098
#
#     accuracy                           0.94      6195
#    macro avg       0.94      0.94      0.94      6195
# weighted avg       0.94      0.94      0.94      6195
#
# accuracy score
# 0.9399515738498789
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[3667  316]
#  [ 158 3824]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94      3983
#            1       0.92      0.96      0.94      3982
#
#     accuracy                           0.94      7965
#    macro avg       0.94      0.94      0.94      7965
# weighted avg       0.94      0.94      0.94      7965
#
# accuracy score
# 0.9404896421845574
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 8
# Index(['melspectrogram', 'melspectrogram_sum', 'melspectrogram_std', 'mfcc',
#        'rms', 'spectral_flatness ', 'spectral_rolloff', 'zero_crossing_rate'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2965  132]
#  [ 120 2978]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      3097
#            1       0.96      0.96      0.96      3098
#
#     accuracy                           0.96      6195
#    macro avg       0.96      0.96      0.96      6195
# weighted avg       0.96      0.96      0.96      6195
#
# accuracy score
# 0.9593220338983051
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[3763  220]
#  [ 156 3826]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95      3983
#            1       0.95      0.96      0.95      3982
#
#     accuracy                           0.95      7965
#    macro avg       0.95      0.95      0.95      7965
# weighted avg       0.95      0.95      0.95      7965
#
# accuracy score
# 0.9527934714375392
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 9
# Index(['melspectrogram', 'melspectrogram_sum', 'melspectrogram_std', 'mfcc',
#        'rms', 'spectral_centroid', 'spectral_contrast', 'spectral_flatness ',
#        'spectral_rolloff'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2875  222]
#  [ 137 2961]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      3097
#            1       0.93      0.96      0.94      3098
#
#     accuracy                           0.94      6195
#    macro avg       0.94      0.94      0.94      6195
# weighted avg       0.94      0.94      0.94      6195
#
# accuracy score
# 0.9420500403551251
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[3666  317]
#  [ 154 3828]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94      3983
#            1       0.92      0.96      0.94      3982
#
#     accuracy                           0.94      7965
#    macro avg       0.94      0.94      0.94      7965
# weighted avg       0.94      0.94      0.94      7965
#
# accuracy score
# 0.9408662900188324
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 9
# Index(['melspectrogram', 'melspectrogram_sum', 'melspectrogram_std', 'mfcc',
#        'rms', 'spectral_centroid', 'spectral_flatness ', 'spectral_rolloff',
#        'zero_crossing_rate'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2965  132]
#  [ 114 2984]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      3097
#            1       0.96      0.96      0.96      3098
#
#     accuracy                           0.96      6195
#    macro avg       0.96      0.96      0.96      6195
# weighted avg       0.96      0.96      0.96      6195
#
# accuracy score
# 0.9602905569007264
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[3763  220]
#  [ 147 3835]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95      3983
#            1       0.95      0.96      0.95      3982
#
#     accuracy                           0.95      7965
#    macro avg       0.95      0.95      0.95      7965
# weighted avg       0.95      0.95      0.95      7965
#
# accuracy score
# 0.9539234149403641
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 10
# Index(['melspectrogram', 'melspectrogram_sum', 'melspectrogram_std', 'mfcc',
#        'rms', 'spectral_centroid', 'spectral_contrast', 'spectral_flatness ',
#        'spectral_rolloff', 'min harm'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2844  253]
#  [ 154 2944]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.93      3097
#            1       0.92      0.95      0.94      3098
#
#     accuracy                           0.93      6195
#    macro avg       0.93      0.93      0.93      6195
# weighted avg       0.93      0.93      0.93      6195
#
# accuracy score
# 0.9343018563357547
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[3650  333]
#  [ 182 3800]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.93      3983
#            1       0.92      0.95      0.94      3982
#
#     accuracy                           0.94      7965
#    macro avg       0.94      0.94      0.94      7965
# weighted avg       0.94      0.94      0.94      7965
#
# accuracy score
# 0.9353421217827997
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 10
# Index(['melspectrogram', 'melspectrogram_sum', 'melspectrogram_std', 'mfcc',
#        'rms', 'spectral_centroid', 'spectral_bandwidth', 'spectral_flatness ',
#        'spectral_rolloff', 'zero_crossing_rate'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2960  137]
#  [ 104 2994]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96      3097
#            1       0.96      0.97      0.96      3098
#
#     accuracy                           0.96      6195
#    macro avg       0.96      0.96      0.96      6195
# weighted avg       0.96      0.96      0.96      6195
#
# accuracy score
# 0.9610976594027442
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[3760  223]
#  [ 127 3855]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96      3983
#            1       0.95      0.97      0.96      3982
#
#     accuracy                           0.96      7965
#    macro avg       0.96      0.96      0.96      7965
# weighted avg       0.96      0.96      0.96      7965
#
# accuracy score
# 0.9560577526679221
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 11
# Index(['melspectrogram', 'melspectrogram_sum', 'melspectrogram_corr',
#        'melspectrogram_std', 'mfcc', 'rms', 'spectral_centroid',
#        'spectral_contrast', 'spectral_flatness ', 'spectral_rolloff',
#        'max harm'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2848  249]
#  [ 137 2961]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94      3097
#            1       0.92      0.96      0.94      3098
#
#     accuracy                           0.94      6195
#    macro avg       0.94      0.94      0.94      6195
# weighted avg       0.94      0.94      0.94      6195
#
# accuracy score
# 0.9376916868442292
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[3619  364]
#  [ 196 3786]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93      3983
#            1       0.91      0.95      0.93      3982
#
#     accuracy                           0.93      7965
#    macro avg       0.93      0.93      0.93      7965
# weighted avg       0.93      0.93      0.93      7965
#
# accuracy score
# 0.9296924042686755
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 11
# Index(['melspectrogram', 'melspectrogram_sum', 'melspectrogram_std', 'mfcc',
#        'rms', 'spectral_centroid', 'spectral_bandwidth', 'spectral_contrast',
#        'spectral_flatness ', 'spectral_rolloff', 'zero_crossing_rate'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2967  130]
#  [  97 3001]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96      3097
#            1       0.96      0.97      0.96      3098
#
#     accuracy                           0.96      6195
#    macro avg       0.96      0.96      0.96      6195
# weighted avg       0.96      0.96      0.96      6195
#
# accuracy score
# 0.9633575464083939
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[3766  217]
#  [ 113 3869]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96      3983
#            1       0.95      0.97      0.96      3982
#
#     accuracy                           0.96      7965
#    macro avg       0.96      0.96      0.96      7965
# weighted avg       0.96      0.96      0.96      7965
#
# accuracy score
# 0.9585687382297552
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 12
# Index(['melspectrogram', 'melspectrogram_sum', 'melspectrogram_std', 'mfcc',
#        'rms', 'spectral_centroid', 'spectral_bandwidth', 'spectral_contrast',
#        'spectral_flatness ', 'spectral_rolloff', 'max harm', 'min harm'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2844  253]
#  [ 138 2960]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94      3097
#            1       0.92      0.96      0.94      3098
#
#     accuracy                           0.94      6195
#    macro avg       0.94      0.94      0.94      6195
# weighted avg       0.94      0.94      0.94      6195
#
# accuracy score
# 0.9368845843422114
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[3641  342]
#  [ 186 3796]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93      3983
#            1       0.92      0.95      0.93      3982
#
#     accuracy                           0.93      7965
#    macro avg       0.93      0.93      0.93      7965
# weighted avg       0.93      0.93      0.93      7965
#
# accuracy score
# 0.9337099811676083
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 12
# Index(['melspectrogram', 'melspectrogram_sum', 'melspectrogram_std', 'mfcc',
#        'rms', 'spectral_centroid', 'spectral_bandwidth', 'spectral_contrast',
#        'spectral_flatness ', 'spectral_rolloff', 'zero_crossing_rate',
#        'min harm'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2962  135]
#  [ 105 2993]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96      3097
#            1       0.96      0.97      0.96      3098
#
#     accuracy                           0.96      6195
#    macro avg       0.96      0.96      0.96      6195
# weighted avg       0.96      0.96      0.96      6195
#
# accuracy score
# 0.9612590799031477
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[3779  204]
#  [ 117 3865]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96      3983
#            1       0.95      0.97      0.96      3982
#
#     accuracy                           0.96      7965
#    macro avg       0.96      0.96      0.96      7965
# weighted avg       0.96      0.96      0.96      7965
#
# accuracy score
# 0.95969868173258
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 13
# Index(['melspectrogram', 'melspectrogram_sum', 'melspectrogram_corr',
#        'melspectrogram_std', 'mfcc', 'rms', 'spectral_centroid',
#        'spectral_contrast', 'spectral_flatness ', 'spectral_rolloff',
#        'zero_crossing_rate', 'max harm', 'min harm'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2855  242]
#  [ 157 2941]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.93      3097
#            1       0.92      0.95      0.94      3098
#
#     accuracy                           0.94      6195
#    macro avg       0.94      0.94      0.94      6195
# weighted avg       0.94      0.94      0.94      6195
#
# accuracy score
# 0.9355932203389831
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[3647  336]
#  [ 206 3776]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.93      3983
#            1       0.92      0.95      0.93      3982
#
#     accuracy                           0.93      7965
#    macro avg       0.93      0.93      0.93      7965
# weighted avg       0.93      0.93      0.93      7965
#
# accuracy score
# 0.9319522912743252
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 13
# Index(['melspectrogram', 'melspectrogram_sum', 'melspectrogram_std', 'mfcc',
#        'rms', 'spectral_centroid', 'spectral_bandwidth', 'spectral_contrast',
#        'spectral_flatness ', 'spectral_rolloff', 'zero_crossing_rate',
#        'max harm', 'min harm'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2971  126]
#  [  97 3001]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96      3097
#            1       0.96      0.97      0.96      3098
#
#     accuracy                           0.96      6195
#    macro avg       0.96      0.96      0.96      6195
# weighted avg       0.96      0.96      0.96      6195
#
# accuracy score
# 0.9640032284100081
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[3773  210]
#  [ 134 3848]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96      3983
#            1       0.95      0.97      0.96      3982
#
#     accuracy                           0.96      7965
#    macro avg       0.96      0.96      0.96      7965
# weighted avg       0.96      0.96      0.96      7965
#
# accuracy score
# 0.956811048336472
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 14
# Index(['melspectrogram', 'melspectrogram_sum', 'melspectrogram_corr',
#        'melspectrogram_std', 'mfcc', 'rms', 'spectral_centroid',
#        'spectral_bandwidth', 'spectral_contrast', 'spectral_flatness ',
#        'spectral_rolloff', 'zero_crossing_rate', 'max harm', 'min harm'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2852  245]
#  [ 157 2941]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.93      3097
#            1       0.92      0.95      0.94      3098
#
#     accuracy                           0.94      6195
#    macro avg       0.94      0.94      0.94      6195
# weighted avg       0.94      0.94      0.94      6195
#
# accuracy score
# 0.9351089588377723
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[3645  338]
#  [ 194 3788]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.93      3983
#            1       0.92      0.95      0.93      3982
#
#     accuracy                           0.93      7965
#    macro avg       0.93      0.93      0.93      7965
# weighted avg       0.93      0.93      0.93      7965
#
# accuracy score
# 0.9332077840552416
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 14
# Index(['melspectrogram', 'melspectrogram_sum', 'melspectrogram_std', 'mfcc',
#        'rms', 'spectral_centroid', 'spectral_bandwidth', 'spectral_contrast',
#        'spectral_flatness ', 'spectral_rolloff', 'zero_crossing_rate',
#        'max harm', 'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2972  125]
#  [ 107 2991]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96      3097
#            1       0.96      0.97      0.96      3098
#
#     accuracy                           0.96      6195
#    macro avg       0.96      0.96      0.96      6195
# weighted avg       0.96      0.96      0.96      6195
#
# accuracy score
# 0.9625504439063761
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[3787  196]
#  [ 151 3831]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96      3983
#            1       0.95      0.96      0.96      3982
#
#     accuracy                           0.96      7965
#    macro avg       0.96      0.96      0.96      7965
# weighted avg       0.96      0.96      0.96      7965
#
# accuracy score
# 0.9564344005021971
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 15
# Index(['melspectrogram', 'melspectrogram_sum', 'melspectrogram_corr',
#        'melspectrogram_std', 'mfcc', 'rms', 'spectral_centroid',
#        'spectral_bandwidth', 'spectral_contrast', 'spectral_flatness ',
#        'spectral_rolloff', 'zero_crossing_rate', 'max harm', 'max perc',
#        'min harm'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2853  244]
#  [ 137 2961]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94      3097
#            1       0.92      0.96      0.94      3098
#
#     accuracy                           0.94      6195
#    macro avg       0.94      0.94      0.94      6195
# weighted avg       0.94      0.94      0.94      6195
#
# accuracy score
# 0.938498789346247
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[3643  340]
#  [ 166 3816]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.91      0.94      3983
#            1       0.92      0.96      0.94      3982
#
#     accuracy                           0.94      7965
#    macro avg       0.94      0.94      0.94      7965
# weighted avg       0.94      0.94      0.94      7965
#
# accuracy score
# 0.9364720652856247
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 15
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_sum',
#        'melspectrogram_std', 'mfcc', 'rms', 'spectral_centroid',
#        'spectral_bandwidth', 'spectral_contrast', 'spectral_flatness ',
#        'spectral_rolloff', 'zero_crossing_rate', 'max harm', 'min harm',
#        'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2976  121]
#  [ 105 2993]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96      3097
#            1       0.96      0.97      0.96      3098
#
#     accuracy                           0.96      6195
#    macro avg       0.96      0.96      0.96      6195
# weighted avg       0.96      0.96      0.96      6195
#
# accuracy score
# 0.9635189669087975
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[3781  202]
#  [ 135 3847]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96      3983
#            1       0.95      0.97      0.96      3982
#
#     accuracy                           0.96      7965
#    macro avg       0.96      0.96      0.96      7965
# weighted avg       0.96      0.96      0.96      7965
#
# accuracy score
# 0.9576898932831136
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 16
# Index(['melspectrogram', 'melspectrogram_sum', 'melspectrogram_corr',
#        'melspectrogram_std', 'mfcc', 'rms', 'spectral_centroid',
#        'spectral_bandwidth', 'spectral_contrast', 'spectral_flatness ',
#        'spectral_rolloff', 'zero_crossing_rate', 'max harm', 'max perc',
#        'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2830  267]
#  [ 150 2948]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93      3097
#            1       0.92      0.95      0.93      3098
#
#     accuracy                           0.93      6195
#    macro avg       0.93      0.93      0.93      6195
# weighted avg       0.93      0.93      0.93      6195
#
# accuracy score
# 0.9326876513317192
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[3639  344]
#  [ 180 3802]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93      3983
#            1       0.92      0.95      0.94      3982
#
#     accuracy                           0.93      7965
#    macro avg       0.93      0.93      0.93      7965
# weighted avg       0.93      0.93      0.93      7965
#
# accuracy score
# 0.9342121782799749
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 16
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_sum',
#        'melspectrogram_std', 'mfcc', 'rms', 'spectral_centroid',
#        'spectral_bandwidth', 'spectral_contrast', 'spectral_flatness ',
#        'spectral_rolloff', 'zero_crossing_rate', 'max harm', 'max perc',
#        'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2988  109]
#  [ 108 2990]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96      3097
#            1       0.96      0.97      0.96      3098
#
#     accuracy                           0.96      6195
#    macro avg       0.96      0.96      0.96      6195
# weighted avg       0.96      0.96      0.96      6195
#
# accuracy score
# 0.9649717514124294
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[3785  198]
#  [ 141 3841]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96      3983
#            1       0.95      0.96      0.96      3982
#
#     accuracy                           0.96      7965
#    macro avg       0.96      0.96      0.96      7965
# weighted avg       0.96      0.96      0.96      7965
#
# accuracy score
# 0.9574387947269303
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 17
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_sum',
#        'melspectrogram_corr', 'melspectrogram_std', 'mfcc', 'rms',
#        'spectral_centroid', 'spectral_bandwidth', 'spectral_contrast',
#        'spectral_flatness ', 'spectral_rolloff', 'zero_crossing_rate',
#        'max harm', 'max perc', 'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2832  265]
#  [ 144 2954]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93      3097
#            1       0.92      0.95      0.94      3098
#
#     accuracy                           0.93      6195
#    macro avg       0.93      0.93      0.93      6195
# weighted avg       0.93      0.93      0.93      6195
#
# accuracy score
# 0.9339790153349475
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[3654  329]
#  [ 183 3799]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.93      3983
#            1       0.92      0.95      0.94      3982
#
#     accuracy                           0.94      7965
#    macro avg       0.94      0.94      0.94      7965
# weighted avg       0.94      0.94      0.94      7965
#
# accuracy score
# 0.9357187696170747
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 17
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_sum',
#        'melspectrogram_corr', 'melspectrogram_std', 'mfcc', 'rms',
#        'spectral_centroid', 'spectral_bandwidth', 'spectral_contrast',
#        'spectral_flatness ', 'spectral_rolloff', 'zero_crossing_rate',
#        'max harm', 'max perc', 'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2992  105]
#  [ 111 2987]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97      3097
#            1       0.97      0.96      0.97      3098
#
#     accuracy                           0.97      6195
#    macro avg       0.97      0.97      0.97      6195
# weighted avg       0.97      0.97      0.97      6195
#
# accuracy score
# 0.9651331719128329
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[3805  178]
#  [ 138 3844]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96      3983
#            1       0.96      0.97      0.96      3982
#
#     accuracy                           0.96      7965
#    macro avg       0.96      0.96      0.96      7965
# weighted avg       0.96      0.96      0.96      7965
#
# accuracy score
# 0.9603264281230383
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 18
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_sum',
#        'melspectrogram_corr', 'melspectrogram_std', 'mfcc', 'rms',
#        'spectral_centroid', 'spectral_bandwidth', 'spectral_contrast',
#        'spectral_flatness ', 'spectral_rolloff', 'zero_crossing_rate',
#        'mean harm', 'max harm', 'max perc', 'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2840  257]
#  [ 146 2952]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.93      3097
#            1       0.92      0.95      0.94      3098
#
#     accuracy                           0.93      6195
#    macro avg       0.94      0.93      0.93      6195
# weighted avg       0.94      0.93      0.93      6195
#
# accuracy score
# 0.9349475383373689
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[3626  357]
#  [ 178 3804]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93      3983
#            1       0.91      0.96      0.93      3982
#
#     accuracy                           0.93      7965
#    macro avg       0.93      0.93      0.93      7965
# weighted avg       0.93      0.93      0.93      7965
#
# accuracy score
# 0.9328311362209667
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 18
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_sum',
#        'melspectrogram_corr', 'melspectrogram_std', 'mfcc', 'rms',
#        'spectral_centroid', 'spectral_bandwidth', 'spectral_contrast',
#        'spectral_flatness ', 'spectral_rolloff', 'zero_crossing_rate',
#        'mean perc', 'max harm', 'max perc', 'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2970  127]
#  [ 112 2986]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      3097
#            1       0.96      0.96      0.96      3098
#
#     accuracy                           0.96      6195
#    macro avg       0.96      0.96      0.96      6195
# weighted avg       0.96      0.96      0.96      6195
#
# accuracy score
# 0.9614205004035512
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[3789  194]
#  [ 149 3833]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96      3983
#            1       0.95      0.96      0.96      3982
#
#     accuracy                           0.96      7965
#    macro avg       0.96      0.96      0.96      7965
# weighted avg       0.96      0.96      0.96      7965
#
# accuracy score
# 0.9569365976145637
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 19
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_sum',
#        'melspectrogram_corr', 'melspectrogram_std', 'mfcc', 'rms',
#        'spectral_centroid', 'spectral_bandwidth', 'spectral_contrast',
#        'spectral_flatness ', 'spectral_rolloff', 'zero_crossing_rate',
#        'mean harm', 'mean perc', 'max harm', 'max perc', 'min harm',
#        'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2841  256]
#  [ 144 2954]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.93      3097
#            1       0.92      0.95      0.94      3098
#
#     accuracy                           0.94      6195
#    macro avg       0.94      0.94      0.94      6195
# weighted avg       0.94      0.94      0.94      6195
#
# accuracy score
# 0.9354317998385795
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[3630  353]
#  [ 186 3796]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93      3983
#            1       0.91      0.95      0.93      3982
#
#     accuracy                           0.93      7965
#    macro avg       0.93      0.93      0.93      7965
# weighted avg       0.93      0.93      0.93      7965
#
# accuracy score
# 0.9323289391086002
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 19
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_sum',
#        'melspectrogram_corr', 'melspectrogram_std', 'mfcc', 'rms',
#        'spectral_centroid', 'spectral_bandwidth', 'spectral_contrast',
#        'spectral_flatness ', 'spectral_rolloff', 'zero_crossing_rate',
#        'mean harm', 'mean perc', 'max harm', 'max perc', 'min harm',
#        'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2989  108]
#  [ 122 2976]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96      3097
#            1       0.96      0.96      0.96      3098
#
#     accuracy                           0.96      6195
#    macro avg       0.96      0.96      0.96      6195
# weighted avg       0.96      0.96      0.96      6195
#
# accuracy score
# 0.9628732849071832
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[3798  185]
#  [ 160 3822]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96      3983
#            1       0.95      0.96      0.96      3982
#
#     accuracy                           0.96      7965
#    macro avg       0.96      0.96      0.96      7965
# weighted avg       0.96      0.96      0.96      7965
#
# accuracy score
# 0.9566854990583804

# %% [markdown]
# ## Select best model based on metrics

# %%
index = 8

# %% [markdown]
# - DecisionTreeClassifier()
# - RandomForestClassifier()

# %%
best_classifier = RandomForestClassifier()

# %%
filename=best_model_selection(X_train, X_test, X_valid, y_train, y_test, y_valid, index, best_classifier)
# Out:
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 8
# Index(['melspectrogram', 'melspectrogram_sum', 'melspectrogram_std', 'mfcc',
#        'rms', 'spectral_centroid', 'spectral_flatness ', 'spectral_rolloff'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2950  147]
#  [ 118 2980]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96      3097
#            1       0.95      0.96      0.96      3098
#
#     accuracy                           0.96      6195
#    macro avg       0.96      0.96      0.96      6195
# weighted avg       0.96      0.96      0.96      6195
#
# accuracy score
# 0.9572235673930589
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[3762  221]
#  [ 149 3833]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95      3983
#            1       0.95      0.96      0.95      3982
#
#     accuracy                           0.95      7965
#    macro avg       0.95      0.95      0.95      7965
# weighted avg       0.95      0.95      0.95      7965
#
# accuracy score
# 0.9535467671060891

# %% [markdown]
# ## Loading Model

# %%
from Preprocessing.ipynb import extract_features

# load the model from disk
loaded_model = pickle.load(open(filename, 'rb'))
file='/home/regis/Desktop/Sound Project/files/fan/0_dB_fan/fan/id_02/abnormal/00000336.wav'
df=extract_features(file)

df
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-224-7173c6b303d0> in <module>
# ----> 1 from .user import User
#       2 from .dir import Dir
#       3
#       4 from Preprocessing.ipynb import extract_features
#       5
#
# ImportError: attempted relative import with no known parent package

# %%
from .user import User
from .dir import Dir
from user import Preprocessing
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-226-d0b3bc64ebbe> in <module>
# ----> 1 from .user import User
#       2 from .dir import Dir
#       3 from user import Preprocessing
#
# ImportError: attempted relative import with no known parent package
