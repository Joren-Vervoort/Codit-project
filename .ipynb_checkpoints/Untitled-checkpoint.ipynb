# %%
import librosa
from librosa import feature
import numpy as np
import pandas as pd

# %%
def Extract_Features(wav_file):

    # loading the file, getting y and sr (sample rate)

    y, sr = librosa.load('normal6.wav')

    # Getting S and phase

    S, phase = librosa.magphase(librosa.stft(y=y))

    # Features for the DataFrame

    chroma_stft = np.mean(librosa.feature.chroma_stft(y=y, sr=sr))

    chroma_cqt = np.mean(librosa.feature.chroma_cqt(y=y, sr=sr))

    chroma_cens = np.mean(librosa.feature.chroma_cens(y=y, sr=sr))

    melspectrogram = np.mean(librosa.feature.melspectrogram(y=y, sr=sr, S=S))

    mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr))

    rms = np.mean(librosa.feature.rms(y=y, S=S))

    spectral_centroid = np.mean(librosa.feature.spectral_centroid(y=y, sr=sr, S=S))

    spectral_bandwidth = np.mean(librosa.feature.spectral_bandwidth(y=y, sr=sr, S=S))

    spectral_contrast = np.mean(librosa.feature.spectral_contrast(y=y, sr=sr, S=S))

    spectral_flatness = np.mean(librosa.feature.spectral_flatness(y=y, S=S))

    spectral_rolloff = np.mean(librosa.feature.spectral_rolloff(y=y, sr=sr, S=S))
    
    poly_features = np.mean(librosa.feature.poly_features(y=y, sr=sr, S=S))

    tonnetz = np.mean(librosa.feature.tonnetz(y=y, sr=sr))

    zero_crossing_rate = np.mean(librosa.feature.zero_crossing_rate(y=y))
    
    # putting them into a dataframe

    df = pd.DataFrame({'chroma_stft': [chroma_stft], 'chroma_cqt': [chroma_cqt], 'chroma_cens' : [chroma_cens], 
                             'melspectrogram' : [melspectrogram], 'mfcc' : [mfcc], 'rms' : [rms],
                        'spectral_centroid' : [spectral_centroid], 'spectral_bandwidth' : [spectral_bandwidth],
                        'spectral_contrast' : [spectral_contrast], 'spectral_flatness ' : [spectral_flatness],
                        'spectral_rolloff' : [spectral_rolloff], 'poly_features' : [poly_features], 
                             'tonnetz' : [tonnetz], 'zero_crossing_rate' : [zero_crossing_rate]})
    
    return df

# %%
print(chroma_stft, chroma_cqt,chroma_cens,melspectrogram,mfcc,rms,spectral_centroid ,spectral_bandwidth ,spectral_contrast,spectral_flatness,spectral_rolloff,poly_features,tonnetz,zero_crossing_rate)
# Out:
# 0.51952004 0.64968586 0.2768664578820685 0.0063003963 -15.342528 0.0029672773 1399.372424976763 1635.5262562424498 21.795883927971023 0.0008519296 2847.1041296584976 0.04339182995610907 -0.012394375426828448 0.06072474079176334

# %%
Extract_Features("normal6.wav")
df
# Out:
#    chroma_stft  chroma_cqt  chroma_cens  melspectrogram       mfcc       rms  \
# 0      0.51952    0.649686     0.276866          0.0063 -15.342528  0.002967
#
#    spectral_centroid  spectral_bandwidth  spectral_contrast  \
# 0        1399.372425         1635.526256          21.795884
#
#    spectral_flatness   spectral_rolloff  poly_features   tonnetz  \
# 0            0.000852        2847.10413       0.043392 -0.012394
#
#    zero_crossing_rate
# 0            0.060725

# %%
import os
import sys

list_normal_6 = []

directory_normal_6 = "C:/Users/vervo/Documents/Codit Project/DataSet/Valves/6_dB_valve.zip/valve/id_00/normal/"

for filename in os.listdir(directory_normal_6):
    file = f"{directory_normal_6}{filename}"
    list_normal_6.append(file)

directory_abnormal_6 = "C:/Users/vervo/Documents/Codit Project/DataSet/Valves/6_dB_valve.zip/valve/id_00/abnormal/"

for filename in os.listdir(directory_abnormal_6):
    file = f"{directory_abnormal_6}{filename}"
    list_abnormal_6.append(file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-472bfece825e> in <module>
#       6 directory_normal_6 = "C://Users/vervo/Documents/Codit Project/DataSet/Valves/6_dB_valve.zip/valve/id_00/normal/"
#       7
# ----> 8 for filename in os.listdir(directory_normal_6):
#       9     file = f"{directory_normal_6}{filename}"
#      10     list_normal_6.append(file)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C://Users/vervo/Documents/Codit Project/DataSet/Valves/6_dB_valve.zip/valve/id_00/normal/'

# %%
import os
import sys

list_normal_6 = []

directory_normal_6 = os.path.abspath("DataSet/Valves/6_dB_valve.zip/valve/id_00/normal")

#for filename in os.listdir(directory_normal_6):
#    print(filename)
directory_normal_6
# Out:
# 'C:\\Users\\vervo\\Documents\\Codit Project\\DataSet\\Valves\\6_dB_valve.zip\\valve\\id_00\\normal'

# %%
for wav_file in list_normal_6:
    df = Extract_Features(wav_file)
    if url == urls[0]:
        df.to_csv('Librosa_features.csv', index=False)
    else:
        df.to_csv('Librosa_features.csv', mode='a', header=False, index=False)

for wav_file in list_abnormal_6:
    df = Extract_Features(wav_file)
    if url == urls[0]:
        df.to_csv('Librosa_features.csv', index=False)
    else:
        df.to_csv('Librosa_features.csv', mode='a', header=False, index=False)

# %%
#DIFFERENT PITCH CLASSES {C, C♯, D, D♯, E , F, F♯, G, G♯, A, A♯, B} MET ALLE HARMONISCHEN, how much of each is present


y, sr = librosa.load('normal6.wav')



S, phase = librosa.magphase(librosa.stft(y=y))

chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)

#chroma_stft = librosa.feature.chroma_stft(S=S, sr=sr) verschillend resultaat (energy spectrum instead of power spectrogram)
chroma_stft

import matplotlib.pyplot as plt
from librosa import display
fig, ax = plt.subplots()
img = librosa.display.specshow(chroma_stft, y_axis='chroma', x_axis='time', ax=ax)
fig.colorbar(img, ax=ax)
ax.set(title='Chromagram')
# Out:
# [Text(0.5, 1.0, 'Chromagram')]

# %%
y, sr = librosa.load('normal6.wav')



S, phase = librosa.magphase(librosa.stft(y=y))

chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)

zero_crossing_rate = np.mean(librosa.feature.zero_crossing_rate(y=y))

# %%
print(zero_crossing_rate)
# Out:
# 0.06072474079176334

# %%
x, sr = librosa.load('normal6.wav')
#Plot the signal:
plt.figure(figsize=(14, 5))
librosa.display.waveplot(x, sr=sr)

# %%
from librosa import display
import matplotlib.pyplot as plt

y, sr = librosa.load('normal6.wav')



S, phase = librosa.magphase(librosa.stft(y=y))


spectral_rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr, S=S)

frames = range(len(librosa.feature.spectral_centroid(y=y, sr=sr, S=S)))
t = librosa.frames_to_time(frames)

import sklearn

def normalize(y, axis=0):
    return sklearn.preprocessing.minmax_scale(y, axis=axis)

# %%
spectral_rolloff = librosa.feature.spectral_rolloff(y, sr=sr)[0]
librosa.display.waveplot(y, sr=sr, alpha=0.4)
plt.plot(t, normalize(spectral_rolloff), color='r')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-b9521927ec90> in <module>
#       1 spectral_rolloff = librosa.feature.spectral_rolloff(y, sr=sr)[0]
#       2 librosa.display.waveplot(y, sr=sr, alpha=0.4)
# ----> 3 plt.plot(t, normalize(spectral_rolloff), color='r')
#
# ~\anaconda3\envs\Codit\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
# -> 2842         **({"data": data} if data is not None else {}), **kwargs)
#    2843
#    2844
#
# ~\anaconda3\envs\Codit\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# ~\anaconda3\envs\Codit\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# ~\anaconda3\envs\Codit\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     397
#     398         if x.shape[0] != y.shape[0]:
# --> 399             raise ValueError(f"x and y must have same first dimension, but "
#     400                              f"have shapes {x.shape} and {y.shape}")
#     401         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (1,) and (431,)

# %%
x, sr = librosa.load('normal6.wav')

mfccs = librosa.feature.mfcc(x, sr=sr)
print(mfccs.shape)
#Displaying  the MFCCs:
librosa.display.specshow(mfccs, sr=sr, x_axis='time')
# Out:
# (20, 431)

# %%
y, sr = librosa.load('normal6.wav')
y_harmonic, y_percussive = librosa.effects.hpss(y)
plt.figure(figsize=(15, 5))
librosa.display.waveplot(y_harmonic, sr=sr, alpha=0.25)
librosa.display.waveplot(y_percussive, sr=sr, color='r', alpha=0.5)
plt.title('Harmonic + Percussive')
# Out:
# Text(0.5, 1.0, 'Harmonic + Percussive')

# %%
y, sr = librosa.load('abnormal6.wav')
y_harmonic, y_percussive = librosa.effects.hpss(y)
plt.figure(figsize=(15, 5))
librosa.display.waveplot(y_harmonic, sr=sr, alpha=0.25)

plt.title('Harmonic')

y, sr = librosa.load('normal6.wav')
y_harmonic, y_percussive = librosa.effects.hpss(y)
plt.figure(figsize=(15, 5))
librosa.display.waveplot(y_harmonic, sr=sr, alpha=0.25)

plt.title('Harmonic')
# Out:
# Text(0.5, 1.0, 'Harmonic')

# %%
y, sr = librosa.load('abnormal6.wav')
y_harmonic, y_percussive = librosa.effects.hpss(y)
plt.figure(figsize=(15, 5))

librosa.display.waveplot(y_percussive, sr=sr, color='r', alpha=0.5)
plt.title('Percussive')

y, sr = librosa.load('normal6.wav')
y_harmonic, y_percussive = librosa.effects.hpss(y)
plt.figure(figsize=(15, 5))

librosa.display.waveplot(y_percussive, sr=sr, color='r', alpha=0.5)
plt.title('Percussive')
# Out:
# Text(0.5, 1.0, 'Percussive')

# %%
y, sr = librosa.load('abnormal6.wav')
y_harmonic, y_percussive = librosa.effects.hpss(y)

print("mean harm:",np.mean(y_harmonic),"\nmean perc:", np.mean(y_percussive))
print("-----------------------------------------------------------------")
print("max harm:",np.max(y_harmonic),"\nmax perc:", np.max(y_percussive))
print("-----------------------------------------------------------------")
print("min harm:",np.min(y_harmonic), "\nmin perc:",np.min(y_percussive))

print("-----------------------------------------------------------------")
print("-----------------------------------------------------------------")
print("-----------------------------------------------------------------")
y, sr = librosa.load('normal6.wav')
y_harmonic, y_percussive = librosa.effects.hpss(y)

print("mean harm:",np.mean(y_harmonic),"\nmean perc:", np.mean(y_percussive))
print("-----------------------------------------------------------------")
print("max harm:",np.max(y_harmonic),"\nmax perc:", np.max(y_percussive))
print("-----------------------------------------------------------------")
print("min harm:",np.min(y_harmonic), "\nmin perc:",np.min(y_percussive))
# Out:
# mean harm: 3.3494317e-07
# mean perc: -4.1690149e-07
# -----------------------------------------------------------------
# max harm: 0.0057080574
# max perc: 0.024672383
# -----------------------------------------------------------------
# min harm: -0.0053073843
# min perc: -0.029307054
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# mean harm: -3.7813524e-07
# mean perc: 4.0128862e-07
# -----------------------------------------------------------------
# max harm: 0.006917637
# max perc: 0.07044074
# -----------------------------------------------------------------
# min harm: -0.006860748
# min perc: -0.06093875
