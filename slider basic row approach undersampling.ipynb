# %%
# Standard libraries

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Handeling .wav files

import librosa
from librosa import feature

# Machine Learning

from sklearn.pipeline import Pipeline

from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import GradientBoostingClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

from sklearn.preprocessing import LabelEncoder, StandardScaler

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score, RepeatedStratifiedKFold

from sklearn.feature_selection import SelectFromModel

from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

from functools import reduce

# data vizualisation

import matplotlib 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def merge_pd(machine):
    
    # Opening the .csv files
    
    df_6dB=pd.read_csv(f'Librosa_features_{machine}_6dB.csv')
    df_0dB=pd.read_csv(f'Librosa_features_{machine}_0dB.csv')
    df_min6dB=pd.read_csv(f'Librosa_features_{machine}_-6dB.csv')
    
    # Dropping the 'Unnamed: 0' column
    
    df_6dB.drop(columns = ['Unnamed: 0'], axis=1, inplace=True)
    df_0dB.drop(columns = ['Unnamed: 0'], axis=1, inplace=True)
    df_min6dB.drop(columns = ['Unnamed: 0'], axis=1, inplace=True)
    

    
    # Merging the .csv files into one DataFrame
    
    data_frames = [df_6dB, df_0dB, df_min6dB]
    df_merged = pd.concat(data_frames)
    
    
    return df_merged

# %%
slider = merge_pd('slider')

# %%
minority_class_len = len(slider[slider['normal(0)/abnormal(1)'] == 1])
majority_class_indices = slider[slider['normal(0)/abnormal(1)'] == 0].index
random_majority_indices = np.random.choice(majority_class_indices, minority_class_len , replace= False)
minority_class_indices  = slider[slider['normal(0)/abnormal(1)'] == 1].index

under_sample_indices = np.concatenate( [minority_class_indices , random_majority_indices])
under_sample = slider.loc[under_sample_indices]
X = under_sample.drop(columns = ['normal(0)/abnormal(1)'])
y = under_sample['normal(0)/abnormal(1)']

# 20% of the overal data will seperated for later validation of the model

X_model, X_valid, y_model, y_valid = train_test_split(X, y, test_size=0.3, random_state = 42, stratify = y)

# 60% of the overal data (75% of X_model, y_model) will be used to create a training set for the model
# 20% of the overal data (25% of X_model, y_model) will be used to create a testing set for the model

X_train, X_test, y_train, y_test = train_test_split(X_model,
                                                   y_model,
                                                   test_size = 1/3,
                                                   random_state = 10, stratify=y_model)

# %%
pipeline = Pipeline([('scaler', StandardScaler()), ('clf', SVC())])

# %%
from IPython.core.display import display, HTML
display(HTML("<style>div.output_scroll { height: 56em; }</style>"))
# Out:
# <style>div.output_scroll { height: 56em; }</style>

# %%
from sklearn.svm import SVC
from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import RepeatedStratifiedKFold
from imblearn.ensemble import EasyEnsembleClassifier
from sklearn.feature_selection import RFE

y_pred = []
clfs = []

clfs.append(DecisionTreeClassifier())
clfs.append(RandomForestClassifier())

for index in range(1,len(X_train.columns)):
    
    for classifier in clfs:
        
        print("----------------------------------------------")
        print("----------------------------------------------")
        print(classifier)
        print("----------------------------------------------")
        print("----------------------------------------------")
        
        sel = RFE(classifier, n_features_to_select = index)
        sel.fit(X_train, y_train)
        features = X_train.columns[sel.get_support()]
        X_train_rfe = sel.transform(X_train)
        X_test_rfe = sel.transform(X_test)
        print('Selected Feature', index)
        print(features)
    
        classifier.fit(X_train_rfe, y_train)
        y_pred= classifier.predict(X_test_rfe)
        scores = cross_val_score(pipeline, X_train_rfe, y_train, cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1))


        print("----------------------------------------------")
        print("TRAIN-TEST")
        print("----------------------------------------------")


        print('confusion matrix', classifier)
        print(confusion_matrix(y_test, y_pred))
        print('classification report')
        print(classification_report(y_test, y_pred))
        print('accuracy score')
        print(accuracy_score(y_test, y_pred))
        
        X_valid_rfe = sel.transform(X_valid)
        y_pred = classifier.predict(X_valid_rfe)

        print("----------------------------------------------")
        print("TRAIN-VALIDATION")
        print("----------------------------------------------")

        print('confusion matrix', classifier)
        print(confusion_matrix(y_valid, y_pred))
        print('classification report')
        print(classification_report(y_valid, y_pred))
        print('accuracy score')
        print(accuracy_score(y_valid, y_pred))
# Out:
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 1
# Index(['spectral_rolloff'], dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1486  383]
#  [ 248 1621]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.86      0.80      0.82      1869
#            1       0.81      0.87      0.84      1869
#
#     accuracy                           0.83      3738
#    macro avg       0.83      0.83      0.83      3738
# weighted avg       0.83      0.83      0.83      3738
#
# accuracy score
# 0.8311931514178705
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1883  520]
#  [ 334 2069]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.85      0.78      0.82      2403
#            1       0.80      0.86      0.83      2403
#
#     accuracy                           0.82      4806
#    macro avg       0.82      0.82      0.82      4806
# weighted avg       0.82      0.82      0.82      4806
#
# accuracy score
# 0.8223054515189346
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 1
# Index(['spectral_rolloff'], dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1483  386]
#  [ 243 1626]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.86      0.79      0.83      1869
#            1       0.81      0.87      0.84      1869
#
#     accuracy                           0.83      3738
#    macro avg       0.83      0.83      0.83      3738
# weighted avg       0.83      0.83      0.83      3738
#
# accuracy score
# 0.8317281968967363
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1879  524]
#  [ 329 2074]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.85      0.78      0.82      2403
#            1       0.80      0.86      0.83      2403
#
#     accuracy                           0.82      4806
#    macro avg       0.82      0.82      0.82      4806
# weighted avg       0.82      0.82      0.82      4806
#
# accuracy score
# 0.8225135247607158
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 2
# Index(['spectral_rolloff', 'min perc'], dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1579  290]
#  [ 170 1699]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.90      0.84      0.87      1869
#            1       0.85      0.91      0.88      1869
#
#     accuracy                           0.88      3738
#    macro avg       0.88      0.88      0.88      3738
# weighted avg       0.88      0.88      0.88      3738
#
# accuracy score
# 0.8769395398608881
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1974  429]
#  [ 214 2189]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.90      0.82      0.86      2403
#            1       0.84      0.91      0.87      2403
#
#     accuracy                           0.87      4806
#    macro avg       0.87      0.87      0.87      4806
# weighted avg       0.87      0.87      0.87      4806
#
# accuracy score
# 0.8662089055347483
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 2
# Index(['spectral_rolloff', 'zero_crossing_rate'], dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1551  318]
#  [ 170 1699]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.90      0.83      0.86      1869
#            1       0.84      0.91      0.87      1869
#
#     accuracy                           0.87      3738
#    macro avg       0.87      0.87      0.87      3738
# weighted avg       0.87      0.87      0.87      3738
#
# accuracy score
# 0.8694489031567684
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2034  369]
#  [ 217 2186]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.90      0.85      0.87      2403
#            1       0.86      0.91      0.88      2403
#
#     accuracy                           0.88      4806
#    macro avg       0.88      0.88      0.88      4806
# weighted avg       0.88      0.88      0.88      4806
#
# accuracy score
# 0.8780690803162713
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 3
# Index(['melspectrogram_corr', 'rms', 'spectral_rolloff'], dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1675  194]
#  [ 118 1751]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.91      1869
#            1       0.90      0.94      0.92      1869
#
#     accuracy                           0.92      3738
#    macro avg       0.92      0.92      0.92      3738
# weighted avg       0.92      0.92      0.92      3738
#
# accuracy score
# 0.9165329052969502
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2117  286]
#  [ 173 2230]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90      2403
#            1       0.89      0.93      0.91      2403
#
#     accuracy                           0.90      4806
#    macro avg       0.91      0.90      0.90      4806
# weighted avg       0.91      0.90      0.90      4806
#
# accuracy score
# 0.9044943820224719
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 3
# Index(['spectral_centroid', 'spectral_rolloff', 'max perc'], dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1646  223]
#  [ 114 1755]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.94      0.88      0.91      1869
#            1       0.89      0.94      0.91      1869
#
#     accuracy                           0.91      3738
#    macro avg       0.91      0.91      0.91      3738
# weighted avg       0.91      0.91      0.91      3738
#
# accuracy score
# 0.9098448368111289
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2121  282]
#  [ 141 2262]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.94      0.88      0.91      2403
#            1       0.89      0.94      0.91      2403
#
#     accuracy                           0.91      4806
#    macro avg       0.91      0.91      0.91      4806
# weighted avg       0.91      0.91      0.91      4806
#
# accuracy score
# 0.9119850187265918
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 4
# Index(['melspectrogram_corr', 'rms', 'spectral_rolloff', 'min perc'], dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1723  146]
#  [  84 1785]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94      1869
#            1       0.92      0.96      0.94      1869
#
#     accuracy                           0.94      3738
#    macro avg       0.94      0.94      0.94      3738
# weighted avg       0.94      0.94      0.94      3738
#
# accuracy score
# 0.9384697699304441
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2155  248]
#  [ 126 2277]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.94      0.90      0.92      2403
#            1       0.90      0.95      0.92      2403
#
#     accuracy                           0.92      4806
#    macro avg       0.92      0.92      0.92      4806
# weighted avg       0.92      0.92      0.92      4806
#
# accuracy score
# 0.922180607573866
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 4
# Index(['melspectrogram_corr', 'rms', 'spectral_rolloff', 'max perc'], dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1758  111]
#  [  69 1800]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95      1869
#            1       0.94      0.96      0.95      1869
#
#     accuracy                           0.95      3738
#    macro avg       0.95      0.95      0.95      3738
# weighted avg       0.95      0.95      0.95      3738
#
# accuracy score
# 0.9518459069020867
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2257  146]
#  [  75 2328]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.95      2403
#            1       0.94      0.97      0.95      2403
#
#     accuracy                           0.95      4806
#    macro avg       0.95      0.95      0.95      4806
# weighted avg       0.95      0.95      0.95      4806
#
# accuracy score
# 0.9540158135663753
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 5
# Index(['melspectrogram_corr', 'rms', 'spectral_rolloff', 'zero_crossing_rate',
#        'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1743  126]
#  [  71 1798]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.95      1869
#            1       0.93      0.96      0.95      1869
#
#     accuracy                           0.95      3738
#    macro avg       0.95      0.95      0.95      3738
# weighted avg       0.95      0.95      0.95      3738
#
# accuracy score
# 0.9472980203317282
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2200  203]
#  [  88 2315]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94      2403
#            1       0.92      0.96      0.94      2403
#
#     accuracy                           0.94      4806
#    macro avg       0.94      0.94      0.94      4806
# weighted avg       0.94      0.94      0.94      4806
#
# accuracy score
# 0.9394506866416978
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 5
# Index(['melspectrogram_corr', 'rms', 'spectral_rolloff', 'zero_crossing_rate',
#        'max perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1782   87]
#  [  64 1805]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96      1869
#            1       0.95      0.97      0.96      1869
#
#     accuracy                           0.96      3738
#    macro avg       0.96      0.96      0.96      3738
# weighted avg       0.96      0.96      0.96      3738
#
# accuracy score
# 0.9596040663456393
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2282  121]
#  [  68 2335]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96      2403
#            1       0.95      0.97      0.96      2403
#
#     accuracy                           0.96      4806
#    macro avg       0.96      0.96      0.96      4806
# weighted avg       0.96      0.96      0.96      4806
#
# accuracy score
# 0.9606741573033708
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 6
# Index(['melspectrogram_corr', 'rms', 'spectral_rolloff', 'zero_crossing_rate',
#        'max perc', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1732  137]
#  [  67 1802]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.94      1869
#            1       0.93      0.96      0.95      1869
#
#     accuracy                           0.95      3738
#    macro avg       0.95      0.95      0.95      3738
# weighted avg       0.95      0.95      0.95      3738
#
# accuracy score
# 0.9454253611556982
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2196  207]
#  [  71 2332]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.91      0.94      2403
#            1       0.92      0.97      0.94      2403
#
#     accuracy                           0.94      4806
#    macro avg       0.94      0.94      0.94      4806
# weighted avg       0.94      0.94      0.94      4806
#
# accuracy score
# 0.9421556387848523
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 6
# Index(['rms', 'spectral_centroid', 'spectral_bandwidth', 'spectral_rolloff',
#        'max perc', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1768  101]
#  [  68 1801]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.95      1869
#            1       0.95      0.96      0.96      1869
#
#     accuracy                           0.95      3738
#    macro avg       0.95      0.95      0.95      3738
# weighted avg       0.95      0.95      0.95      3738
#
# accuracy score
# 0.954788657035848
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2258  145]
#  [  93 2310]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95      2403
#            1       0.94      0.96      0.95      2403
#
#     accuracy                           0.95      4806
#    macro avg       0.95      0.95      0.95      4806
# weighted avg       0.95      0.95      0.95      4806
#
# accuracy score
# 0.9504785684560966
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 7
# Index(['melspectrogram_max', 'melspectrogram_corr', 'rms', 'spectral_rolloff',
#        'zero_crossing_rate', 'max perc', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1760  109]
#  [  56 1813]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96      1869
#            1       0.94      0.97      0.96      1869
#
#     accuracy                           0.96      3738
#    macro avg       0.96      0.96      0.96      3738
# weighted avg       0.96      0.96      0.96      3738
#
# accuracy score
# 0.9558587479935795
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2208  195]
#  [  67 2336]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.92      0.94      2403
#            1       0.92      0.97      0.95      2403
#
#     accuracy                           0.95      4806
#    macro avg       0.95      0.95      0.95      4806
# weighted avg       0.95      0.95      0.95      4806
#
# accuracy score
# 0.94548481065335
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 7
# Index(['rms', 'spectral_centroid', 'spectral_bandwidth', 'spectral_rolloff',
#        'zero_crossing_rate', 'max perc', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1784   85]
#  [  67 1802]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96      1869
#            1       0.95      0.96      0.96      1869
#
#     accuracy                           0.96      3738
#    macro avg       0.96      0.96      0.96      3738
# weighted avg       0.96      0.96      0.96      3738
#
# accuracy score
# 0.9593365436062066
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2267  136]
#  [  80 2323]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.95      2403
#            1       0.94      0.97      0.96      2403
#
#     accuracy                           0.96      4806
#    macro avg       0.96      0.96      0.96      4806
# weighted avg       0.96      0.96      0.96      4806
#
# accuracy score
# 0.9550561797752809
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 8
# Index(['melspectrogram_corr', 'mfcc', 'rms', 'spectral_bandwidth',
#        'spectral_rolloff', 'zero_crossing_rate', 'max perc', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1716  153]
#  [  69 1800]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94      1869
#            1       0.92      0.96      0.94      1869
#
#     accuracy                           0.94      3738
#    macro avg       0.94      0.94      0.94      3738
# weighted avg       0.94      0.94      0.94      3738
#
# accuracy score
# 0.9406099518459069
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2174  229]
#  [  84 2319]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93      2403
#            1       0.91      0.97      0.94      2403
#
#     accuracy                           0.93      4806
#    macro avg       0.94      0.93      0.93      4806
# weighted avg       0.94      0.93      0.93      4806
#
# accuracy score
# 0.9348730753225135
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 8
# Index(['melspectrogram_corr', 'rms', 'spectral_centroid', 'spectral_bandwidth',
#        'spectral_rolloff', 'zero_crossing_rate', 'max perc', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1798   71]
#  [  53 1816]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97      1869
#            1       0.96      0.97      0.97      1869
#
#     accuracy                           0.97      3738
#    macro avg       0.97      0.97      0.97      3738
# weighted avg       0.97      0.97      0.97      3738
#
# accuracy score
# 0.9668271803103263
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2296  107]
#  [  64 2339]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96      2403
#            1       0.96      0.97      0.96      2403
#
#     accuracy                           0.96      4806
#    macro avg       0.96      0.96      0.96      4806
# weighted avg       0.96      0.96      0.96      4806
#
# accuracy score
# 0.9644194756554307
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 9
# Index(['melspectrogram_max', 'melspectrogram_corr', 'mfcc', 'rms',
#        'spectral_bandwidth', 'spectral_rolloff', 'zero_crossing_rate',
#        'max perc', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1739  130]
#  [  69 1800]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.95      1869
#            1       0.93      0.96      0.95      1869
#
#     accuracy                           0.95      3738
#    macro avg       0.95      0.95      0.95      3738
# weighted avg       0.95      0.95      0.95      3738
#
# accuracy score
# 0.9467629748528625
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2216  187]
#  [  69 2334]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.92      0.95      2403
#            1       0.93      0.97      0.95      2403
#
#     accuracy                           0.95      4806
#    macro avg       0.95      0.95      0.95      4806
# weighted avg       0.95      0.95      0.95      4806
#
# accuracy score
# 0.9467332501040366
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 9
# Index(['melspectrogram_corr', 'melspectrogram_std', 'rms', 'spectral_centroid',
#        'spectral_bandwidth', 'spectral_rolloff', 'zero_crossing_rate',
#        'max perc', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1800   69]
#  [  55 1814]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97      1869
#            1       0.96      0.97      0.97      1869
#
#     accuracy                           0.97      3738
#    macro avg       0.97      0.97      0.97      3738
# weighted avg       0.97      0.97      0.97      3738
#
# accuracy score
# 0.9668271803103263
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2299  104]
#  [  65 2338]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96      2403
#            1       0.96      0.97      0.97      2403
#
#     accuracy                           0.96      4806
#    macro avg       0.96      0.96      0.96      4806
# weighted avg       0.96      0.96      0.96      4806
#
# accuracy score
# 0.9648356221389929
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 10
# Index(['melspectrogram_max', 'melspectrogram_corr', 'mfcc', 'rms',
#        'spectral_bandwidth', 'spectral_flatness ', 'spectral_rolloff',
#        'zero_crossing_rate', 'max perc', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1729  140]
#  [  78 1791]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.94      1869
#            1       0.93      0.96      0.94      1869
#
#     accuracy                           0.94      3738
#    macro avg       0.94      0.94      0.94      3738
# weighted avg       0.94      0.94      0.94      3738
#
# accuracy score
# 0.9416800428036383
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2189  214]
#  [  78 2325]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.91      0.94      2403
#            1       0.92      0.97      0.94      2403
#
#     accuracy                           0.94      4806
#    macro avg       0.94      0.94      0.94      4806
# weighted avg       0.94      0.94      0.94      4806
#
# accuracy score
# 0.9392426133999168
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 10
# Index(['melspectrogram_max', 'melspectrogram_corr', 'melspectrogram_std',
#        'rms', 'spectral_centroid', 'spectral_bandwidth', 'spectral_rolloff',
#        'zero_crossing_rate', 'max perc', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1818   51]
#  [  62 1807]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      1869
#            1       0.97      0.97      0.97      1869
#
#     accuracy                           0.97      3738
#    macro avg       0.97      0.97      0.97      3738
# weighted avg       0.97      0.97      0.97      3738
#
# accuracy score
# 0.9697699304440878
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2305   98]
#  [  76 2327]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96      2403
#            1       0.96      0.97      0.96      2403
#
#     accuracy                           0.96      4806
#    macro avg       0.96      0.96      0.96      4806
# weighted avg       0.96      0.96      0.96      4806
#
# accuracy score
# 0.9637952559300874
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 11
# Index(['melspectrogram_max', 'melspectrogram_sum', 'melspectrogram_corr',
#        'mfcc', 'rms', 'spectral_bandwidth', 'spectral_flatness ',
#        'spectral_rolloff', 'zero_crossing_rate', 'max perc', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1736  133]
#  [  74 1795]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.94      1869
#            1       0.93      0.96      0.95      1869
#
#     accuracy                           0.94      3738
#    macro avg       0.95      0.94      0.94      3738
# weighted avg       0.95      0.94      0.94      3738
#
# accuracy score
# 0.9446227929373997
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2193  210]
#  [  88 2315]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.91      0.94      2403
#            1       0.92      0.96      0.94      2403
#
#     accuracy                           0.94      4806
#    macro avg       0.94      0.94      0.94      4806
# weighted avg       0.94      0.94      0.94      4806
#
# accuracy score
# 0.9379941739492301
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 11
# Index(['melspectrogram_max', 'melspectrogram_corr', 'melspectrogram_std',
#        'rms', 'spectral_centroid', 'spectral_bandwidth', 'spectral_flatness ',
#        'spectral_rolloff', 'zero_crossing_rate', 'max perc', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1811   58]
#  [  60 1809]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      1869
#            1       0.97      0.97      0.97      1869
#
#     accuracy                           0.97      3738
#    macro avg       0.97      0.97      0.97      3738
# weighted avg       0.97      0.97      0.97      3738
#
# accuracy score
# 0.9684323167469235
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2308   95]
#  [  78 2325]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96      2403
#            1       0.96      0.97      0.96      2403
#
#     accuracy                           0.96      4806
#    macro avg       0.96      0.96      0.96      4806
# weighted avg       0.96      0.96      0.96      4806
#
# accuracy score
# 0.9640033291718685
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 12
# Index(['melspectrogram_max', 'melspectrogram_sum', 'melspectrogram_corr',
#        'mfcc', 'rms', 'spectral_bandwidth', 'spectral_flatness ',
#        'spectral_rolloff', 'zero_crossing_rate', 'max perc', 'min harm',
#        'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1734  135]
#  [  71 1798]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.94      1869
#            1       0.93      0.96      0.95      1869
#
#     accuracy                           0.94      3738
#    macro avg       0.95      0.94      0.94      3738
# weighted avg       0.95      0.94      0.94      3738
#
# accuracy score
# 0.9448903156768326
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2195  208]
#  [  82 2321]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.91      0.94      2403
#            1       0.92      0.97      0.94      2403
#
#     accuracy                           0.94      4806
#    macro avg       0.94      0.94      0.94      4806
# weighted avg       0.94      0.94      0.94      4806
#
# accuracy score
# 0.939658759883479
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 12
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_corr',
#        'melspectrogram_std', 'rms', 'spectral_centroid', 'spectral_bandwidth',
#        'spectral_flatness ', 'spectral_rolloff', 'zero_crossing_rate',
#        'max perc', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1819   50]
#  [  58 1811]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      1869
#            1       0.97      0.97      0.97      1869
#
#     accuracy                           0.97      3738
#    macro avg       0.97      0.97      0.97      3738
# weighted avg       0.97      0.97      0.97      3738
#
# accuracy score
# 0.971107544141252
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2326   77]
#  [  74 2329]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      2403
#            1       0.97      0.97      0.97      2403
#
#     accuracy                           0.97      4806
#    macro avg       0.97      0.97      0.97      4806
# weighted avg       0.97      0.97      0.97      4806
#
# accuracy score
# 0.9685809404910528
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 13
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_corr', 'mfcc',
#        'rms', 'spectral_centroid', 'spectral_bandwidth', 'spectral_flatness ',
#        'spectral_rolloff', 'zero_crossing_rate', 'max harm', 'max perc',
#        'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1730  139]
#  [  60 1809]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95      1869
#            1       0.93      0.97      0.95      1869
#
#     accuracy                           0.95      3738
#    macro avg       0.95      0.95      0.95      3738
# weighted avg       0.95      0.95      0.95      3738
#
# accuracy score
# 0.9467629748528625
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2176  227]
#  [  81 2322]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.91      0.93      2403
#            1       0.91      0.97      0.94      2403
#
#     accuracy                           0.94      4806
#    macro avg       0.94      0.94      0.94      4806
# weighted avg       0.94      0.94      0.94      4806
#
# accuracy score
# 0.9359134415314191
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 13
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_corr',
#        'melspectrogram_std', 'mfcc', 'rms', 'spectral_centroid',
#        'spectral_bandwidth', 'spectral_flatness ', 'spectral_rolloff',
#        'zero_crossing_rate', 'max perc', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1819   50]
#  [  58 1811]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      1869
#            1       0.97      0.97      0.97      1869
#
#     accuracy                           0.97      3738
#    macro avg       0.97      0.97      0.97      3738
# weighted avg       0.97      0.97      0.97      3738
#
# accuracy score
# 0.971107544141252
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2322   81]
#  [  74 2329]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      2403
#            1       0.97      0.97      0.97      2403
#
#     accuracy                           0.97      4806
#    macro avg       0.97      0.97      0.97      4806
# weighted avg       0.97      0.97      0.97      4806
#
# accuracy score
# 0.9677486475239284
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 14
# Index(['melspectrogram_max', 'melspectrogram_sum', 'melspectrogram_corr',
#        'mfcc', 'rms', 'spectral_centroid', 'spectral_bandwidth',
#        'spectral_flatness ', 'spectral_rolloff', 'zero_crossing_rate',
#        'max harm', 'max perc', 'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1728  141]
#  [  70 1799]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94      1869
#            1       0.93      0.96      0.94      1869
#
#     accuracy                           0.94      3738
#    macro avg       0.94      0.94      0.94      3738
# weighted avg       0.94      0.94      0.94      3738
#
# accuracy score
# 0.9435527019796682
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2172  231]
#  [  83 2320]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93      2403
#            1       0.91      0.97      0.94      2403
#
#     accuracy                           0.93      4806
#    macro avg       0.94      0.93      0.93      4806
# weighted avg       0.94      0.93      0.93      4806
#
# accuracy score
# 0.9346650020807324
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 14
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_sum',
#        'melspectrogram_corr', 'melspectrogram_std', 'rms', 'spectral_centroid',
#        'spectral_bandwidth', 'spectral_flatness ', 'spectral_rolloff',
#        'zero_crossing_rate', 'max harm', 'max perc', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1825   44]
#  [  61 1808]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97      1869
#            1       0.98      0.97      0.97      1869
#
#     accuracy                           0.97      3738
#    macro avg       0.97      0.97      0.97      3738
# weighted avg       0.97      0.97      0.97      3738
#
# accuracy score
# 0.9719101123595506
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2319   84]
#  [  71 2332]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      2403
#            1       0.97      0.97      0.97      2403
#
#     accuracy                           0.97      4806
#    macro avg       0.97      0.97      0.97      4806
# weighted avg       0.97      0.97      0.97      4806
#
# accuracy score
# 0.9677486475239284
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 15
# Index(['melspectrogram_max', 'melspectrogram_sum', 'melspectrogram_corr',
#        'mfcc', 'rms', 'spectral_centroid', 'spectral_bandwidth',
#        'spectral_contrast', 'spectral_flatness ', 'spectral_rolloff',
#        'zero_crossing_rate', 'max harm', 'max perc', 'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1728  141]
#  [  63 1806]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94      1869
#            1       0.93      0.97      0.95      1869
#
#     accuracy                           0.95      3738
#    macro avg       0.95      0.95      0.95      3738
# weighted avg       0.95      0.95      0.95      3738
#
# accuracy score
# 0.9454253611556982
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2179  224]
#  [  69 2334]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.91      0.94      2403
#            1       0.91      0.97      0.94      2403
#
#     accuracy                           0.94      4806
#    macro avg       0.94      0.94      0.94      4806
# weighted avg       0.94      0.94      0.94      4806
#
# accuracy score
# 0.9390345401581357
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 15
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_sum',
#        'melspectrogram_corr', 'melspectrogram_std', 'mfcc', 'rms',
#        'spectral_centroid', 'spectral_bandwidth', 'spectral_flatness ',
#        'spectral_rolloff', 'zero_crossing_rate', 'max perc', 'min harm',
#        'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1818   51]
#  [  56 1813]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      1869
#            1       0.97      0.97      0.97      1869
#
#     accuracy                           0.97      3738
#    macro avg       0.97      0.97      0.97      3738
# weighted avg       0.97      0.97      0.97      3738
#
# accuracy score
# 0.9713750668806849
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2324   79]
#  [  64 2339]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      2403
#            1       0.97      0.97      0.97      2403
#
#     accuracy                           0.97      4806
#    macro avg       0.97      0.97      0.97      4806
# weighted avg       0.97      0.97      0.97      4806
#
# accuracy score
# 0.9702455264253017
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 16
# Index(['melspectrogram_max', 'melspectrogram_sum', 'melspectrogram_corr',
#        'mfcc', 'rms', 'spectral_centroid', 'spectral_bandwidth',
#        'spectral_contrast', 'spectral_flatness ', 'spectral_rolloff',
#        'zero_crossing_rate', 'mean perc', 'max harm', 'max perc', 'min harm',
#        'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1724  145]
#  [  64 1805]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94      1869
#            1       0.93      0.97      0.95      1869
#
#     accuracy                           0.94      3738
#    macro avg       0.94      0.94      0.94      3738
# weighted avg       0.94      0.94      0.94      3738
#
# accuracy score
# 0.944087747458534
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2173  230]
#  [  83 2320]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93      2403
#            1       0.91      0.97      0.94      2403
#
#     accuracy                           0.93      4806
#    macro avg       0.94      0.93      0.93      4806
# weighted avg       0.94      0.93      0.93      4806
#
# accuracy score
# 0.9348730753225135
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 16
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_sum',
#        'melspectrogram_corr', 'melspectrogram_std', 'mfcc', 'rms',
#        'spectral_centroid', 'spectral_bandwidth', 'spectral_flatness ',
#        'spectral_rolloff', 'zero_crossing_rate', 'max harm', 'max perc',
#        'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1821   48]
#  [  58 1811]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      1869
#            1       0.97      0.97      0.97      1869
#
#     accuracy                           0.97      3738
#    macro avg       0.97      0.97      0.97      3738
# weighted avg       0.97      0.97      0.97      3738
#
# accuracy score
# 0.9716425896201177
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2323   80]
#  [  68 2335]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      2403
#            1       0.97      0.97      0.97      2403
#
#     accuracy                           0.97      4806
#    macro avg       0.97      0.97      0.97      4806
# weighted avg       0.97      0.97      0.97      4806
#
# accuracy score
# 0.9692051602163961
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 17
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_corr', 'mfcc',
#        'rms', 'spectral_centroid', 'spectral_bandwidth', 'spectral_contrast',
#        'spectral_flatness ', 'spectral_rolloff', 'zero_crossing_rate',
#        'mean harm', 'mean perc', 'max harm', 'max perc', 'min harm',
#        'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1729  140]
#  [  65 1804]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.94      1869
#            1       0.93      0.97      0.95      1869
#
#     accuracy                           0.95      3738
#    macro avg       0.95      0.95      0.95      3738
# weighted avg       0.95      0.95      0.95      3738
#
# accuracy score
# 0.9451578384162653
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2174  229]
#  [  85 2318]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93      2403
#            1       0.91      0.96      0.94      2403
#
#     accuracy                           0.93      4806
#    macro avg       0.94      0.93      0.93      4806
# weighted avg       0.94      0.93      0.93      4806
#
# accuracy score
# 0.9346650020807324
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 17
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_sum',
#        'melspectrogram_corr', 'melspectrogram_std', 'mfcc', 'rms',
#        'spectral_centroid', 'spectral_bandwidth', 'spectral_contrast',
#        'spectral_flatness ', 'spectral_rolloff', 'zero_crossing_rate',
#        'max harm', 'max perc', 'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1827   42]
#  [  56 1813]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97      1869
#            1       0.98      0.97      0.97      1869
#
#     accuracy                           0.97      3738
#    macro avg       0.97      0.97      0.97      3738
# weighted avg       0.97      0.97      0.97      3738
#
# accuracy score
# 0.9737827715355806
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2330   73]
#  [  67 2336]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      2403
#            1       0.97      0.97      0.97      2403
#
#     accuracy                           0.97      4806
#    macro avg       0.97      0.97      0.97      4806
# weighted avg       0.97      0.97      0.97      4806
#
# accuracy score
# 0.970869746150645
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 18
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_sum',
#        'melspectrogram_corr', 'melspectrogram_std', 'mfcc', 'rms',
#        'spectral_centroid', 'spectral_bandwidth', 'spectral_contrast',
#        'spectral_flatness ', 'spectral_rolloff', 'zero_crossing_rate',
#        'mean perc', 'max harm', 'max perc', 'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1728  141]
#  [  63 1806]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94      1869
#            1       0.93      0.97      0.95      1869
#
#     accuracy                           0.95      3738
#    macro avg       0.95      0.95      0.95      3738
# weighted avg       0.95      0.95      0.95      3738
#
# accuracy score
# 0.9454253611556982
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2181  222]
#  [  81 2322]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.91      0.94      2403
#            1       0.91      0.97      0.94      2403
#
#     accuracy                           0.94      4806
#    macro avg       0.94      0.94      0.94      4806
# weighted avg       0.94      0.94      0.94      4806
#
# accuracy score
# 0.9369538077403246
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 18
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_sum',
#        'melspectrogram_corr', 'melspectrogram_std', 'mfcc', 'rms',
#        'spectral_centroid', 'spectral_bandwidth', 'spectral_contrast',
#        'spectral_flatness ', 'spectral_rolloff', 'zero_crossing_rate',
#        'mean perc', 'max harm', 'max perc', 'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1826   43]
#  [  55 1814]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97      1869
#            1       0.98      0.97      0.97      1869
#
#     accuracy                           0.97      3738
#    macro avg       0.97      0.97      0.97      3738
# weighted avg       0.97      0.97      0.97      3738
#
# accuracy score
# 0.9737827715355806
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2325   78]
#  [  62 2341]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      2403
#            1       0.97      0.97      0.97      2403
#
#     accuracy                           0.97      4806
#    macro avg       0.97      0.97      0.97      4806
# weighted avg       0.97      0.97      0.97      4806
#
# accuracy score
# 0.970869746150645
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 19
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_sum',
#        'melspectrogram_corr', 'melspectrogram_std', 'mfcc', 'rms',
#        'spectral_centroid', 'spectral_bandwidth', 'spectral_contrast',
#        'spectral_flatness ', 'spectral_rolloff', 'zero_crossing_rate',
#        'mean harm', 'mean perc', 'max harm', 'max perc', 'min harm',
#        'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1723  146]
#  [  65 1804]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94      1869
#            1       0.93      0.97      0.94      1869
#
#     accuracy                           0.94      3738
#    macro avg       0.94      0.94      0.94      3738
# weighted avg       0.94      0.94      0.94      3738
#
# accuracy score
# 0.9435527019796682
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[2180  223]
#  [  79 2324]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.91      0.94      2403
#            1       0.91      0.97      0.94      2403
#
#     accuracy                           0.94      4806
#    macro avg       0.94      0.94      0.94      4806
# weighted avg       0.94      0.94      0.94      4806
#
# accuracy score
# 0.9371618809821057
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 19
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_sum',
#        'melspectrogram_corr', 'melspectrogram_std', 'mfcc', 'rms',
#        'spectral_centroid', 'spectral_bandwidth', 'spectral_contrast',
#        'spectral_flatness ', 'spectral_rolloff', 'zero_crossing_rate',
#        'mean harm', 'mean perc', 'max harm', 'max perc', 'min harm',
#        'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1821   48]
#  [  63 1806]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      1869
#            1       0.97      0.97      0.97      1869
#
#     accuracy                           0.97      3738
#    macro avg       0.97      0.97      0.97      3738
# weighted avg       0.97      0.97      0.97      3738
#
# accuracy score
# 0.9703049759229535
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[2327   76]
#  [  63 2340]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      2403
#            1       0.97      0.97      0.97      2403
#
#     accuracy                           0.97      4806
#    macro avg       0.97      0.97      0.97      4806
# weighted avg       0.97      0.97      0.97      4806
#
# accuracy score
# 0.9710778193924261

# %% [markdown]
# ![Screenshot%20from%202021-04-01%2015-32-58.png](attachment:Screenshot%20from%202021-04-01%2015-32-58.png)
