# %%
# Standard libraries

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Handeling .wav files

import librosa
from librosa import feature

# Machine Learning

from sklearn.pipeline import Pipeline

from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import GradientBoostingClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

from sklearn.preprocessing import LabelEncoder, StandardScaler

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score, RepeatedStratifiedKFold

from sklearn.feature_selection import SelectFromModel

from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

from functools import reduce

# data vizualisation

import matplotlib 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def merge_pd(machine):
    
    # Opening the .csv files
    
    df_6dB=pd.read_csv(f'Librosa_features_{machine}_6dB.csv')
    df_0dB=pd.read_csv(f'Librosa_features_{machine}_0dB.csv')
    df_min6dB=pd.read_csv(f'Librosa_features_{machine}_-6dB.csv')
    
    # Dropping the 'Unnamed: 0' column
    
    df_6dB.drop(columns = ['Unnamed: 0'], axis=1, inplace=True)
    df_0dB.drop(columns = ['Unnamed: 0'], axis=1, inplace=True)
    df_min6dB.drop(columns = ['Unnamed: 0'], axis=1, inplace=True)
    

    
    # Merging the .csv files into one DataFrame
    
    data_frames = [df_6dB, df_0dB, df_min6dB]
    df_merged = pd.concat(data_frames)
    
    
    return df_merged

# %%
valve = merge_pd('valve')

# %%
minority_class_len = len(valve[valve['normal(0)/abnormal(1)'] == 1])
majority_class_indices = valve[valve['normal(0)/abnormal(1)'] == 0].index
random_majority_indices = np.random.choice(majority_class_indices, minority_class_len , replace= False)
minority_class_indices  = valve[valve['normal(0)/abnormal(1)'] == 1].index

under_sample_indices = np.concatenate( [minority_class_indices , random_majority_indices])
under_sample = valve.loc[under_sample_indices]
X = under_sample.drop(columns = ['normal(0)/abnormal(1)'])
y = under_sample['normal(0)/abnormal(1)']

# 20% of the overal data will seperated for later validation of the model

X_model, X_valid, y_model, y_valid = train_test_split(X, y, test_size=0.3, random_state = 42, stratify = y)

# 60% of the overal data (75% of X_model, y_model) will be used to create a training set for the model
# 20% of the overal data (25% of X_model, y_model) will be used to create a testing set for the model

X_train, X_test, y_train, y_test = train_test_split(X_model,
                                                   y_model,
                                                   test_size = 1/3,
                                                   random_state = 10, stratify=y_model)

# %%
pipeline = Pipeline([('scaler', StandardScaler()), ('clf', SVC())])

# %%
from IPython.core.display import display, HTML
display(HTML("<style>div.output_scroll { height: 56em; }</style>"))
# Out:
# <style>div.output_scroll { height: 56em; }</style>

# %%
from sklearn.svm import SVC
from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import RepeatedStratifiedKFold
from imblearn.ensemble import EasyEnsembleClassifier
from sklearn.feature_selection import RFE

y_pred = []
clfs = []

clfs.append(DecisionTreeClassifier())
clfs.append(RandomForestClassifier())

for index in range(1,len(X_train.columns)):
    
    for classifier in clfs:
        
        print("----------------------------------------------")
        print("----------------------------------------------")
        print(classifier)
        print("----------------------------------------------")
        print("----------------------------------------------")
        
        sel = RFE(classifier, n_features_to_select = index)
        sel.fit(X_train, y_train)
        features = X_train.columns[sel.get_support()]
        X_train_rfe = sel.transform(X_train)
        X_test_rfe = sel.transform(X_test)
        print('Selected Feature', index)
        print(features)
    
        classifier.fit(X_train_rfe, y_train)
        y_pred= classifier.predict(X_test_rfe)
        scores = cross_val_score(pipeline, X_train_rfe, y_train, cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1))


        print("----------------------------------------------")
        print("TRAIN-TEST")
        print("----------------------------------------------")


        print('confusion matrix', classifier)
        print(confusion_matrix(y_test, y_pred))
        print('classification report')
        print(classification_report(y_test, y_pred))
        print('accuracy score')
        print(accuracy_score(y_test, y_pred))
        
        X_valid_rfe = sel.transform(X_valid)
        y_pred = classifier.predict(X_valid_rfe)

        print("----------------------------------------------")
        print("TRAIN-VALIDATION")
        print("----------------------------------------------")

        print('confusion matrix', classifier)
        print(confusion_matrix(y_valid, y_pred))
        print('classification report')
        print(classification_report(y_valid, y_pred))
        print('accuracy score')
        print(accuracy_score(y_valid, y_pred))
# Out:
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 1
# Index(['max perc'], dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[768 238]
#  [115 891]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.87      0.76      0.81      1006
#            1       0.79      0.89      0.83      1006
#
#     accuracy                           0.82      2012
#    macro avg       0.83      0.82      0.82      2012
# weighted avg       0.83      0.82      0.82      2012
#
# accuracy score
# 0.8245526838966203
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1017  277]
#  [ 141 1152]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.88      0.79      0.83      1294
#            1       0.81      0.89      0.85      1293
#
#     accuracy                           0.84      2587
#    macro avg       0.84      0.84      0.84      2587
# weighted avg       0.84      0.84      0.84      2587
#
# accuracy score
# 0.8384228836490143
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 1
# Index(['max perc'], dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[768 238]
#  [115 891]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.87      0.76      0.81      1006
#            1       0.79      0.89      0.83      1006
#
#     accuracy                           0.82      2012
#    macro avg       0.83      0.82      0.82      2012
# weighted avg       0.83      0.82      0.82      2012
#
# accuracy score
# 0.8245526838966203
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1017  277]
#  [ 141 1152]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.88      0.79      0.83      1294
#            1       0.81      0.89      0.85      1293
#
#     accuracy                           0.84      2587
#    macro avg       0.84      0.84      0.84      2587
# weighted avg       0.84      0.84      0.84      2587
#
# accuracy score
# 0.8384228836490143
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 2
# Index(['melspectrogram_max', 'max perc'], dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[810 196]
#  [ 85 921]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.91      0.81      0.85      1006
#            1       0.82      0.92      0.87      1006
#
#     accuracy                           0.86      2012
#    macro avg       0.86      0.86      0.86      2012
# weighted avg       0.86      0.86      0.86      2012
#
# accuracy score
# 0.860337972166998
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1076  218]
#  [ 113 1180]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.90      0.83      0.87      1294
#            1       0.84      0.91      0.88      1293
#
#     accuracy                           0.87      2587
#    macro avg       0.87      0.87      0.87      2587
# weighted avg       0.87      0.87      0.87      2587
#
# accuracy score
# 0.8720525705450328
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 2
# Index(['max perc', 'min perc'], dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[852 154]
#  [108 898]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.89      0.85      0.87      1006
#            1       0.85      0.89      0.87      1006
#
#     accuracy                           0.87      2012
#    macro avg       0.87      0.87      0.87      2012
# weighted avg       0.87      0.87      0.87      2012
#
# accuracy score
# 0.8697813121272365
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1123  171]
#  [ 123 1170]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.90      0.87      0.88      1294
#            1       0.87      0.90      0.89      1293
#
#     accuracy                           0.89      2587
#    macro avg       0.89      0.89      0.89      2587
# weighted avg       0.89      0.89      0.89      2587
#
# accuracy score
# 0.8863548511789718
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 3
# Index(['melspectrogram_max', 'max perc', 'min perc'], dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[840 166]
#  [ 73 933]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.83      0.88      1006
#            1       0.85      0.93      0.89      1006
#
#     accuracy                           0.88      2012
#    macro avg       0.88      0.88      0.88      2012
# weighted avg       0.88      0.88      0.88      2012
#
# accuracy score
# 0.8812127236580517
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1087  207]
#  [  89 1204]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.84      0.88      1294
#            1       0.85      0.93      0.89      1293
#
#     accuracy                           0.89      2587
#    macro avg       0.89      0.89      0.89      2587
# weighted avg       0.89      0.89      0.89      2587
#
# accuracy score
# 0.8855817549284886
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 3
# Index(['melspectrogram_max', 'max perc', 'min perc'], dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[879 127]
#  [ 88 918]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.91      0.87      0.89      1006
#            1       0.88      0.91      0.90      1006
#
#     accuracy                           0.89      2012
#    macro avg       0.89      0.89      0.89      2012
# weighted avg       0.89      0.89      0.89      2012
#
# accuracy score
# 0.893141153081511
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1169  125]
#  [  98 1195]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91      1294
#            1       0.91      0.92      0.91      1293
#
#     accuracy                           0.91      2587
#    macro avg       0.91      0.91      0.91      2587
# weighted avg       0.91      0.91      0.91      2587
#
# accuracy score
# 0.9137997680711248
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 4
# Index(['melspectrogram_max', 'melspectrogram_corr', 'max perc', 'min perc'], dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[829 177]
#  [ 81 925]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.91      0.82      0.87      1006
#            1       0.84      0.92      0.88      1006
#
#     accuracy                           0.87      2012
#    macro avg       0.88      0.87      0.87      2012
# weighted avg       0.88      0.87      0.87      2012
#
# accuracy score
# 0.8717693836978131
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1082  212]
#  [  93 1200]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.84      0.88      1294
#            1       0.85      0.93      0.89      1293
#
#     accuracy                           0.88      2587
#    macro avg       0.89      0.88      0.88      2587
# weighted avg       0.89      0.88      0.88      2587
#
# accuracy score
# 0.8821028218013143
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 4
# Index(['melspectrogram_max', 'melspectrogram_corr', 'max perc', 'min perc'], dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[907  99]
#  [ 82 924]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91      1006
#            1       0.90      0.92      0.91      1006
#
#     accuracy                           0.91      2012
#    macro avg       0.91      0.91      0.91      2012
# weighted avg       0.91      0.91      0.91      2012
#
# accuracy score
# 0.9100397614314115
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1176  118]
#  [  89 1204]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92      1294
#            1       0.91      0.93      0.92      1293
#
#     accuracy                           0.92      2587
#    macro avg       0.92      0.92      0.92      2587
# weighted avg       0.92      0.92      0.92      2587
#
# accuracy score
# 0.9199845380749904
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 5
# Index(['melspectrogram_max', 'melspectrogram_corr', 'zero_crossing_rate',
#        'max perc', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[845 161]
#  [ 93 913]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.90      0.84      0.87      1006
#            1       0.85      0.91      0.88      1006
#
#     accuracy                           0.87      2012
#    macro avg       0.88      0.87      0.87      2012
# weighted avg       0.88      0.87      0.87      2012
#
# accuracy score
# 0.8737574552683897
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1086  208]
#  [ 111 1182]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.91      0.84      0.87      1294
#            1       0.85      0.91      0.88      1293
#
#     accuracy                           0.88      2587
#    macro avg       0.88      0.88      0.88      2587
# weighted avg       0.88      0.88      0.88      2587
#
# accuracy score
# 0.876691148047932
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 5
# Index(['melspectrogram_max', 'melspectrogram_corr', 'rms', 'max perc',
#        'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[917  89]
#  [ 80 926]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.92      1006
#            1       0.91      0.92      0.92      1006
#
#     accuracy                           0.92      2012
#    macro avg       0.92      0.92      0.92      2012
# weighted avg       0.92      0.92      0.92      2012
#
# accuracy score
# 0.9160039761431411
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1186  108]
#  [  82 1211]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93      1294
#            1       0.92      0.94      0.93      1293
#
#     accuracy                           0.93      2587
#    macro avg       0.93      0.93      0.93      2587
# weighted avg       0.93      0.93      0.93      2587
#
# accuracy score
# 0.9265558562040974
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 6
# Index(['melspectrogram_max', 'melspectrogram_corr', 'mfcc', 'rms', 'max perc',
#        'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[839 167]
#  [ 59 947]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.93      0.83      0.88      1006
#            1       0.85      0.94      0.89      1006
#
#     accuracy                           0.89      2012
#    macro avg       0.89      0.89      0.89      2012
# weighted avg       0.89      0.89      0.89      2012
#
# accuracy score
# 0.8876739562624254
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1132  162]
#  [  70 1223]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.94      0.87      0.91      1294
#            1       0.88      0.95      0.91      1293
#
#     accuracy                           0.91      2587
#    macro avg       0.91      0.91      0.91      2587
# weighted avg       0.91      0.91      0.91      2587
#
# accuracy score
# 0.9103208349439506
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 6
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_corr', 'rms',
#        'max perc', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[923  83]
#  [ 78 928]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92      1006
#            1       0.92      0.92      0.92      1006
#
#     accuracy                           0.92      2012
#    macro avg       0.92      0.92      0.92      2012
# weighted avg       0.92      0.92      0.92      2012
#
# accuracy score
# 0.9199801192842942
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1199   95]
#  [  78 1215]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93      1294
#            1       0.93      0.94      0.93      1293
#
#     accuracy                           0.93      2587
#    macro avg       0.93      0.93      0.93      2587
# weighted avg       0.93      0.93      0.93      2587
#
# accuracy score
# 0.9331271743332045
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 7
# Index(['melspectrogram_max', 'melspectrogram_corr', 'melspectrogram_std',
#        'zero_crossing_rate', 'max perc', 'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[853 153]
#  [ 81 925]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.91      0.85      0.88      1006
#            1       0.86      0.92      0.89      1006
#
#     accuracy                           0.88      2012
#    macro avg       0.89      0.88      0.88      2012
# weighted avg       0.89      0.88      0.88      2012
#
# accuracy score
# 0.8836978131212724
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1126  168]
#  [  96 1197]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.87      0.90      1294
#            1       0.88      0.93      0.90      1293
#
#     accuracy                           0.90      2587
#    macro avg       0.90      0.90      0.90      2587
# weighted avg       0.90      0.90      0.90      2587
#
# accuracy score
# 0.8979512949362196
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 7
# Index(['melspectrogram_max', 'melspectrogram_sum', 'melspectrogram_corr',
#        'rms', 'max perc', 'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[927  79]
#  [ 88 918]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.91      0.92      0.92      1006
#            1       0.92      0.91      0.92      1006
#
#     accuracy                           0.92      2012
#    macro avg       0.92      0.92      0.92      2012
# weighted avg       0.92      0.92      0.92      2012
#
# accuracy score
# 0.9169980119284294
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1200   94]
#  [  86 1207]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93      1294
#            1       0.93      0.93      0.93      1293
#
#     accuracy                           0.93      2587
#    macro avg       0.93      0.93      0.93      2587
# weighted avg       0.93      0.93      0.93      2587
#
# accuracy score
# 0.9304213374565133
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 8
# Index(['melspectrogram_max', 'melspectrogram_corr', 'mfcc', 'rms',
#        'zero_crossing_rate', 'max harm', 'max perc', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[851 155]
#  [ 76 930]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.85      0.88      1006
#            1       0.86      0.92      0.89      1006
#
#     accuracy                           0.89      2012
#    macro avg       0.89      0.89      0.89      2012
# weighted avg       0.89      0.89      0.89      2012
#
# accuracy score
# 0.8851888667992047
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1119  175]
#  [ 101 1192]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.86      0.89      1294
#            1       0.87      0.92      0.90      1293
#
#     accuracy                           0.89      2587
#    macro avg       0.89      0.89      0.89      2587
# weighted avg       0.89      0.89      0.89      2587
#
# accuracy score
# 0.8933127174333204
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 8
# Index(['melspectrogram_max', 'melspectrogram_sum', 'melspectrogram_corr',
#        'melspectrogram_std', 'rms', 'max perc', 'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[928  78]
#  [ 75 931]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.92      1006
#            1       0.92      0.93      0.92      1006
#
#     accuracy                           0.92      2012
#    macro avg       0.92      0.92      0.92      2012
# weighted avg       0.92      0.92      0.92      2012
#
# accuracy score
# 0.9239562624254473
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1210   84]
#  [  87 1206]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.93      1294
#            1       0.93      0.93      0.93      1293
#
#     accuracy                           0.93      2587
#    macro avg       0.93      0.93      0.93      2587
# weighted avg       0.93      0.93      0.93      2587
#
# accuracy score
# 0.9339002705836876
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 9
# Index(['melspectrogram_max', 'melspectrogram_corr', 'melspectrogram_std',
#        'mfcc', 'spectral_contrast', 'zero_crossing_rate', 'max perc',
#        'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[856 150]
#  [ 64 942]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.93      0.85      0.89      1006
#            1       0.86      0.94      0.90      1006
#
#     accuracy                           0.89      2012
#    macro avg       0.90      0.89      0.89      2012
# weighted avg       0.90      0.89      0.89      2012
#
# accuracy score
# 0.8936381709741551
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1118  176]
#  [  89 1204]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.93      0.86      0.89      1294
#            1       0.87      0.93      0.90      1293
#
#     accuracy                           0.90      2587
#    macro avg       0.90      0.90      0.90      2587
# weighted avg       0.90      0.90      0.90      2587
#
# accuracy score
# 0.897564746810978
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 9
# Index(['melspectrogram_max', 'melspectrogram_sum', 'melspectrogram_corr',
#        'melspectrogram_std', 'rms', 'spectral_flatness ', 'max perc',
#        'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[923  83]
#  [ 83 923]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92      1006
#            1       0.92      0.92      0.92      1006
#
#     accuracy                           0.92      2012
#    macro avg       0.92      0.92      0.92      2012
# weighted avg       0.92      0.92      0.92      2012
#
# accuracy score
# 0.9174950298210736
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1206   88]
#  [  85 1208]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93      1294
#            1       0.93      0.93      0.93      1293
#
#     accuracy                           0.93      2587
#    macro avg       0.93      0.93      0.93      2587
# weighted avg       0.93      0.93      0.93      2587
#
# accuracy score
# 0.9331271743332045
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 10
# Index(['melspectrogram_max', 'melspectrogram_corr', 'melspectrogram_std',
#        'mfcc', 'rms', 'zero_crossing_rate', 'max harm', 'max perc', 'min harm',
#        'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[858 148]
#  [ 73 933]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.85      0.89      1006
#            1       0.86      0.93      0.89      1006
#
#     accuracy                           0.89      2012
#    macro avg       0.89      0.89      0.89      2012
# weighted avg       0.89      0.89      0.89      2012
#
# accuracy score
# 0.8901590457256461
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1092  202]
#  [  95 1198]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.84      0.88      1294
#            1       0.86      0.93      0.89      1293
#
#     accuracy                           0.89      2587
#    macro avg       0.89      0.89      0.89      2587
# weighted avg       0.89      0.89      0.89      2587
#
# accuracy score
# 0.885195206803247
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 10
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_corr',
#        'melspectrogram_std', 'rms', 'zero_crossing_rate', 'max harm',
#        'max perc', 'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[924  82]
#  [ 76 930]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92      1006
#            1       0.92      0.92      0.92      1006
#
#     accuracy                           0.92      2012
#    macro avg       0.92      0.92      0.92      2012
# weighted avg       0.92      0.92      0.92      2012
#
# accuracy score
# 0.9214711729622267
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1200   94]
#  [  83 1210]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93      1294
#            1       0.93      0.94      0.93      1293
#
#     accuracy                           0.93      2587
#    macro avg       0.93      0.93      0.93      2587
# weighted avg       0.93      0.93      0.93      2587
#
# accuracy score
# 0.9315809818322381
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 11
# Index(['melspectrogram_max', 'melspectrogram_corr', 'melspectrogram_std',
#        'mfcc', 'rms', 'spectral_centroid', 'zero_crossing_rate', 'max harm',
#        'max perc', 'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[847 159]
#  [ 88 918]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.91      0.84      0.87      1006
#            1       0.85      0.91      0.88      1006
#
#     accuracy                           0.88      2012
#    macro avg       0.88      0.88      0.88      2012
# weighted avg       0.88      0.88      0.88      2012
#
# accuracy score
# 0.8772365805168986
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1112  182]
#  [ 107 1186]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.91      0.86      0.88      1294
#            1       0.87      0.92      0.89      1293
#
#     accuracy                           0.89      2587
#    macro avg       0.89      0.89      0.89      2587
# weighted avg       0.89      0.89      0.89      2587
#
# accuracy score
# 0.8882875918051798
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 11
# Index(['melspectrogram_max', 'melspectrogram_sum', 'melspectrogram_corr',
#        'melspectrogram_std', 'rms', 'spectral_bandwidth', 'spectral_flatness ',
#        'zero_crossing_rate', 'max perc', 'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[926  80]
#  [ 80 926]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92      1006
#            1       0.92      0.92      0.92      1006
#
#     accuracy                           0.92      2012
#    macro avg       0.92      0.92      0.92      2012
# weighted avg       0.92      0.92      0.92      2012
#
# accuracy score
# 0.9204771371769384
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1197   97]
#  [  85 1208]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93      1294
#            1       0.93      0.93      0.93      1293
#
#     accuracy                           0.93      2587
#    macro avg       0.93      0.93      0.93      2587
# weighted avg       0.93      0.93      0.93      2587
#
# accuracy score
# 0.9296482412060302
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 12
# Index(['melspectrogram_max', 'melspectrogram_corr', 'melspectrogram_std',
#        'mfcc', 'spectral_bandwidth', 'spectral_contrast', 'zero_crossing_rate',
#        'mean perc', 'max harm', 'max perc', 'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[859 147]
#  [ 84 922]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.91      0.85      0.88      1006
#            1       0.86      0.92      0.89      1006
#
#     accuracy                           0.89      2012
#    macro avg       0.89      0.89      0.89      2012
# weighted avg       0.89      0.89      0.89      2012
#
# accuracy score
# 0.8851888667992047
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1098  196]
#  [ 114 1179]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.91      0.85      0.88      1294
#            1       0.86      0.91      0.88      1293
#
#     accuracy                           0.88      2587
#    macro avg       0.88      0.88      0.88      2587
# weighted avg       0.88      0.88      0.88      2587
#
# accuracy score
# 0.8801700811751063
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 12
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_sum',
#        'melspectrogram_corr', 'melspectrogram_std', 'rms',
#        'spectral_bandwidth', 'zero_crossing_rate', 'max harm', 'max perc',
#        'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[924  82]
#  [ 80 926]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92      1006
#            1       0.92      0.92      0.92      1006
#
#     accuracy                           0.92      2012
#    macro avg       0.92      0.92      0.92      2012
# weighted avg       0.92      0.92      0.92      2012
#
# accuracy score
# 0.9194831013916501
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1199   95]
#  [  85 1208]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93      1294
#            1       0.93      0.93      0.93      1293
#
#     accuracy                           0.93      2587
#    macro avg       0.93      0.93      0.93      2587
# weighted avg       0.93      0.93      0.93      2587
#
# accuracy score
# 0.9304213374565133
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 13
# Index(['melspectrogram_max', 'melspectrogram_corr', 'melspectrogram_std',
#        'mfcc', 'rms', 'spectral_contrast', 'spectral_rolloff',
#        'zero_crossing_rate', 'mean perc', 'max harm', 'max perc', 'min harm',
#        'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[846 160]
#  [ 85 921]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.91      0.84      0.87      1006
#            1       0.85      0.92      0.88      1006
#
#     accuracy                           0.88      2012
#    macro avg       0.88      0.88      0.88      2012
# weighted avg       0.88      0.88      0.88      2012
#
# accuracy score
# 0.8782306163021869
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1102  192]
#  [  98 1195]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.85      0.88      1294
#            1       0.86      0.92      0.89      1293
#
#     accuracy                           0.89      2587
#    macro avg       0.89      0.89      0.89      2587
# weighted avg       0.89      0.89      0.89      2587
#
# accuracy score
# 0.8879010436799382
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 13
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_sum',
#        'melspectrogram_corr', 'melspectrogram_std', 'mfcc', 'rms',
#        'spectral_bandwidth', 'zero_crossing_rate', 'max harm', 'max perc',
#        'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[928  78]
#  [ 81 925]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92      1006
#            1       0.92      0.92      0.92      1006
#
#     accuracy                           0.92      2012
#    macro avg       0.92      0.92      0.92      2012
# weighted avg       0.92      0.92      0.92      2012
#
# accuracy score
# 0.9209741550695825
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1206   88]
#  [  84 1209]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93      1294
#            1       0.93      0.94      0.93      1293
#
#     accuracy                           0.93      2587
#    macro avg       0.93      0.93      0.93      2587
# weighted avg       0.93      0.93      0.93      2587
#
# accuracy score
# 0.9335137224584461
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 14
# Index(['melspectrogram_max', 'melspectrogram_corr', 'melspectrogram_std',
#        'mfcc', 'rms', 'spectral_centroid', 'spectral_bandwidth',
#        'spectral_contrast', 'zero_crossing_rate', 'mean perc', 'max harm',
#        'max perc', 'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[832 174]
#  [ 84 922]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.91      0.83      0.87      1006
#            1       0.84      0.92      0.88      1006
#
#     accuracy                           0.87      2012
#    macro avg       0.87      0.87      0.87      2012
# weighted avg       0.87      0.87      0.87      2012
#
# accuracy score
# 0.8717693836978131
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1115  179]
#  [ 105 1188]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.91      0.86      0.89      1294
#            1       0.87      0.92      0.89      1293
#
#     accuracy                           0.89      2587
#    macro avg       0.89      0.89      0.89      2587
# weighted avg       0.89      0.89      0.89      2587
#
# accuracy score
# 0.8902203324313878
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 14
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_sum',
#        'melspectrogram_corr', 'melspectrogram_std', 'mfcc', 'rms',
#        'spectral_bandwidth', 'spectral_flatness ', 'zero_crossing_rate',
#        'max harm', 'max perc', 'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[922  84]
#  [ 79 927]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92      1006
#            1       0.92      0.92      0.92      1006
#
#     accuracy                           0.92      2012
#    macro avg       0.92      0.92      0.92      2012
# weighted avg       0.92      0.92      0.92      2012
#
# accuracy score
# 0.918986083499006
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1202   92]
#  [  83 1210]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93      1294
#            1       0.93      0.94      0.93      1293
#
#     accuracy                           0.93      2587
#    macro avg       0.93      0.93      0.93      2587
# weighted avg       0.93      0.93      0.93      2587
#
# accuracy score
# 0.9323540780827213
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 15
# Index(['melspectrogram_max', 'melspectrogram_sum', 'melspectrogram_corr',
#        'melspectrogram_std', 'mfcc', 'rms', 'spectral_contrast',
#        'spectral_flatness ', 'spectral_rolloff', 'zero_crossing_rate',
#        'mean perc', 'max harm', 'max perc', 'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[846 160]
#  [ 72 934]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.84      0.88      1006
#            1       0.85      0.93      0.89      1006
#
#     accuracy                           0.88      2012
#    macro avg       0.89      0.88      0.88      2012
# weighted avg       0.89      0.88      0.88      2012
#
# accuracy score
# 0.8846918489065606
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1108  186]
#  [  93 1200]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.86      0.89      1294
#            1       0.87      0.93      0.90      1293
#
#     accuracy                           0.89      2587
#    macro avg       0.89      0.89      0.89      2587
# weighted avg       0.89      0.89      0.89      2587
#
# accuracy score
# 0.8921530730575957
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 15
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_sum',
#        'melspectrogram_corr', 'melspectrogram_std', 'mfcc', 'rms',
#        'spectral_bandwidth', 'spectral_contrast', 'spectral_flatness ',
#        'zero_crossing_rate', 'max harm', 'max perc', 'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[923  83]
#  [ 84 922]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92      1006
#            1       0.92      0.92      0.92      1006
#
#     accuracy                           0.92      2012
#    macro avg       0.92      0.92      0.92      2012
# weighted avg       0.92      0.92      0.92      2012
#
# accuracy score
# 0.9169980119284294
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1214   80]
#  [  90 1203]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.93      1294
#            1       0.94      0.93      0.93      1293
#
#     accuracy                           0.93      2587
#    macro avg       0.93      0.93      0.93      2587
# weighted avg       0.93      0.93      0.93      2587
#
# accuracy score
# 0.9342868187089293
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 16
# Index(['melspectrogram_max', 'melspectrogram_corr', 'melspectrogram_std',
#        'mfcc', 'rms', 'spectral_centroid', 'spectral_bandwidth',
#        'spectral_contrast', 'spectral_flatness ', 'zero_crossing_rate',
#        'mean harm', 'mean perc', 'max harm', 'max perc', 'min harm',
#        'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[846 160]
#  [ 78 928]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.84      0.88      1006
#            1       0.85      0.92      0.89      1006
#
#     accuracy                           0.88      2012
#    macro avg       0.88      0.88      0.88      2012
# weighted avg       0.88      0.88      0.88      2012
#
# accuracy score
# 0.8817097415506958
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1093  201]
#  [ 102 1191]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.91      0.84      0.88      1294
#            1       0.86      0.92      0.89      1293
#
#     accuracy                           0.88      2587
#    macro avg       0.89      0.88      0.88      2587
# weighted avg       0.89      0.88      0.88      2587
#
# accuracy score
# 0.8828759180517974
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 16
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_sum',
#        'melspectrogram_corr', 'melspectrogram_std', 'mfcc', 'rms',
#        'spectral_centroid', 'spectral_bandwidth', 'spectral_contrast',
#        'spectral_flatness ', 'zero_crossing_rate', 'max harm', 'max perc',
#        'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[926  80]
#  [ 83 923]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92      1006
#            1       0.92      0.92      0.92      1006
#
#     accuracy                           0.92      2012
#    macro avg       0.92      0.92      0.92      2012
# weighted avg       0.92      0.92      0.92      2012
#
# accuracy score
# 0.918986083499006
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1214   80]
#  [  88 1205]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.94      1294
#            1       0.94      0.93      0.93      1293
#
#     accuracy                           0.94      2587
#    macro avg       0.94      0.94      0.94      2587
# weighted avg       0.94      0.94      0.94      2587
#
# accuracy score
# 0.9350599149594124
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 17
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_corr',
#        'melspectrogram_std', 'mfcc', 'rms', 'spectral_centroid',
#        'spectral_bandwidth', 'spectral_contrast', 'spectral_flatness ',
#        'spectral_rolloff', 'zero_crossing_rate', 'mean perc', 'max harm',
#        'max perc', 'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[836 170]
#  [ 78 928]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.91      0.83      0.87      1006
#            1       0.85      0.92      0.88      1006
#
#     accuracy                           0.88      2012
#    macro avg       0.88      0.88      0.88      2012
# weighted avg       0.88      0.88      0.88      2012
#
# accuracy score
# 0.8767395626242545
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1108  186]
#  [ 102 1191]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.86      0.88      1294
#            1       0.86      0.92      0.89      1293
#
#     accuracy                           0.89      2587
#    macro avg       0.89      0.89      0.89      2587
# weighted avg       0.89      0.89      0.89      2587
#
# accuracy score
# 0.8886741399304213
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 17
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_sum',
#        'melspectrogram_corr', 'melspectrogram_std', 'mfcc', 'rms',
#        'spectral_centroid', 'spectral_bandwidth', 'spectral_contrast',
#        'spectral_flatness ', 'spectral_rolloff', 'zero_crossing_rate',
#        'max harm', 'max perc', 'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[924  82]
#  [ 86 920]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.91      0.92      0.92      1006
#            1       0.92      0.91      0.92      1006
#
#     accuracy                           0.92      2012
#    macro avg       0.92      0.92      0.92      2012
# weighted avg       0.92      0.92      0.92      2012
#
# accuracy score
# 0.9165009940357853
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1214   80]
#  [  94 1199]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.93      1294
#            1       0.94      0.93      0.93      1293
#
#     accuracy                           0.93      2587
#    macro avg       0.93      0.93      0.93      2587
# weighted avg       0.93      0.93      0.93      2587
#
# accuracy score
# 0.9327406262079629
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 18
# Index(['melspectrogram_max', 'melspectrogram_sum', 'melspectrogram_corr',
#        'melspectrogram_std', 'mfcc', 'rms', 'spectral_centroid',
#        'spectral_bandwidth', 'spectral_contrast', 'spectral_flatness ',
#        'spectral_rolloff', 'zero_crossing_rate', 'mean harm', 'mean perc',
#        'max harm', 'max perc', 'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[839 167]
#  [ 73 933]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.83      0.87      1006
#            1       0.85      0.93      0.89      1006
#
#     accuracy                           0.88      2012
#    macro avg       0.88      0.88      0.88      2012
# weighted avg       0.88      0.88      0.88      2012
#
# accuracy score
# 0.8807157057654076
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1107  187]
#  [ 104 1189]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.91      0.86      0.88      1294
#            1       0.86      0.92      0.89      1293
#
#     accuracy                           0.89      2587
#    macro avg       0.89      0.89      0.89      2587
# weighted avg       0.89      0.89      0.89      2587
#
# accuracy score
# 0.8875144955546965
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 18
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_sum',
#        'melspectrogram_corr', 'melspectrogram_std', 'mfcc', 'rms',
#        'spectral_centroid', 'spectral_bandwidth', 'spectral_contrast',
#        'spectral_flatness ', 'spectral_rolloff', 'zero_crossing_rate',
#        'mean perc', 'max harm', 'max perc', 'min harm', 'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[920  86]
#  [ 79 927]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.92      1006
#            1       0.92      0.92      0.92      1006
#
#     accuracy                           0.92      2012
#    macro avg       0.92      0.92      0.92      2012
# weighted avg       0.92      0.92      0.92      2012
#
# accuracy score
# 0.9179920477137177
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1208   86]
#  [  86 1207]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93      1294
#            1       0.93      0.93      0.93      1293
#
#     accuracy                           0.93      2587
#    macro avg       0.93      0.93      0.93      2587
# weighted avg       0.93      0.93      0.93      2587
#
# accuracy score
# 0.9335137224584461
# ----------------------------------------------
# ----------------------------------------------
# DecisionTreeClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 19
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_sum',
#        'melspectrogram_corr', 'melspectrogram_std', 'mfcc', 'rms',
#        'spectral_centroid', 'spectral_bandwidth', 'spectral_contrast',
#        'spectral_flatness ', 'spectral_rolloff', 'zero_crossing_rate',
#        'mean harm', 'mean perc', 'max harm', 'max perc', 'min harm',
#        'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[831 175]
#  [ 75 931]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.83      0.87      1006
#            1       0.84      0.93      0.88      1006
#
#     accuracy                           0.88      2012
#    macro avg       0.88      0.88      0.88      2012
# weighted avg       0.88      0.88      0.88      2012
#
# accuracy score
# 0.8757455268389662
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix DecisionTreeClassifier()
# [[1096  198]
#  [ 108 1185]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.91      0.85      0.88      1294
#            1       0.86      0.92      0.89      1293
#
#     accuracy                           0.88      2587
#    macro avg       0.88      0.88      0.88      2587
# weighted avg       0.88      0.88      0.88      2587
#
# accuracy score
# 0.8817162736760726
# ----------------------------------------------
# ----------------------------------------------
# RandomForestClassifier()
# ----------------------------------------------
# ----------------------------------------------
# Selected Feature 19
# Index(['melspectrogram', 'melspectrogram_max', 'melspectrogram_sum',
#        'melspectrogram_corr', 'melspectrogram_std', 'mfcc', 'rms',
#        'spectral_centroid', 'spectral_bandwidth', 'spectral_contrast',
#        'spectral_flatness ', 'spectral_rolloff', 'zero_crossing_rate',
#        'mean harm', 'mean perc', 'max harm', 'max perc', 'min harm',
#        'min perc'],
#       dtype='object')
# ----------------------------------------------
# TRAIN-TEST
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[923  83]
#  [ 82 924]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92      1006
#            1       0.92      0.92      0.92      1006
#
#     accuracy                           0.92      2012
#    macro avg       0.92      0.92      0.92      2012
# weighted avg       0.92      0.92      0.92      2012
#
# accuracy score
# 0.9179920477137177
# ----------------------------------------------
# TRAIN-VALIDATION
# ----------------------------------------------
# confusion matrix RandomForestClassifier()
# [[1208   86]
#  [  92 1201]]
# classification report
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93      1294
#            1       0.93      0.93      0.93      1293
#
#     accuracy                           0.93      2587
#    macro avg       0.93      0.93      0.93      2587
# weighted avg       0.93      0.93      0.93      2587
#
# accuracy score
# 0.9311944337069965

# %% [markdown]
# ![Screenshot%20from%202021-04-01%2015-23-36.png](attachment:Screenshot%20from%202021-04-01%2015-23-36.png)
